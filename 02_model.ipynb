# %% [markdown]
# <!-- # Langchain은 다양한 LLM(대규모 언어 모델)을 지원한다
# -	대규모 언어 모델(LLM, Large Language Model)을 개발하는 회사들은 사용자가 자신의 애플리케이션에서 LLM을 손쉽게 활용할 수 있도록 API(Application Programming Interface) 서비스를 제공하고 있다.
# -	하지만 각 LLM은 고유한 API 호출 라이브러리(Library)를 제공하기 때문에, 개발자는 동일한 작업을 수행하더라도 LLM에 따라 다른 코드를 작성해야 하는 번거로움이 있다.
# -	Langchain은 이러한 문제를 해결하기 위해 다양한 LLM의 API를 통합적으로 지원한다.
# -	여러 LLM을 동일한 인터페이스(interface)로 호출할 수 있게 하여 특정 모델에 종속되지 않도록 하고, 필요에 따라 쉽게 다른 모델로 전환할 수 있다.
# -	Langchain이 지원하는 주요 LLM 목록
#     - https://python.langchain.com/docs/integrations/chat/#featured-providers -->

# %%
uv pip install langchain langchain-classic langchain-community python-dotenv

# %% [markdown]
# # OpenAI 모델 사용
# - https://platform.openai.com
#
# ## 결제
# 1. 로그인 후 Billing 페이지로 이동.
#    - **신용카드가 등록된 경우 바로 충전할 수 있다.**
#    - setting -> Billing
#
#    ![openai_payment.png](figures/openai_payment.png)
#    - 금액 입력 후 `continue`
#    - 다음 페이지에서 세금 포함 결제 금액 나오면 `Confirm`  한다.
#
# 2. 신용카드 등록
#    - Payment methods 탭을 선택하고 카드를 등록한다.
#
#    ![openai_payment2.png](figures/openai_payment2.png)
#
#    - 등록이 끝나면 최초 구매를 진행한다. $5 ~ $100 사이의 금액을 선택할 수 있다.
#    - 자동 충전을 설정하고 싶다면 automatic recharge 를 활성화 하고 아래 추가 설정에 입력한다.
#      - 자동 충전은 특정 금액 이하로 떨어지면 자동으로 충전한다. (**비활성화**)
#
#    ![openai_payment3.png](figures/openai_payment3.png)
#
# 3. 수동으로 **추가 결제하기**
#    - Billing 페이지의 Overview에서 `Add to credit balance` 를 클릭한 뒤 금액을 입력하고 결제한다.
#
# ## 사용량 확인
# - profile/설정 -> Usage 에서 확인

# %% [markdown]
# ## API Key 생성
#
# ![openai_create_apikey.png](figures/openai_create_apikey.png)
#
# - 로그인 -> Dashboard -> API Keys -> Create New Secreat Key
# > Settings -> API Keys
#
# ## API Key 등록
# - 환경변수에 등록
#   - 변수이름: OPENAI_API_KEY
#   - 값: 생성된 키
# - dotenv를 이용해서 load
#   - Working directory에  `.env` 파일 생성하고 `OPENAI_API_KEY=생성된키` 추가한다.
#   - load_dotenv() 호출 하면 .env 파일에 있는 값을 읽은 뒤 환경변수로 등록한다.
# - **주의**
#   - 생성된 API Key는 노출되면 안된다.
#   - API Key가 저장된 파일(코드나 설정파일)이 github에 올라가 공개되서는 안된다.
#
# ## 사용 비용 확인
# - settings -> Usage 에서 확인
#
# ## OpenAI LLM 모델들
# -  OpenAI LLM 모델: https://platform.openai.com/docs/models
# -  모델별 가격: https://platform.openai.com/docs/pricing
# -  토큰사이즈 확인: https://platform.openai.com/tokenizer
#    -  1토큰: 영어 3\~4글자 정도, 한글: 대략 1\~2글자 정도
#    -  모델이 업데이트 되면서 토큰 사이즈도 조금씩 커지고 있다.

# %% [markdown]
# ## OpenAI 를 연동하기 위한 package 설치
# ```bash
# pip install langchain-openai -qU
# ```
#
# - OpenAI 자체 라이브러리 설치
#     - `pip install openai -qU`
#     - langchain-openai를 설치하면 같이 설치 된다.

# %%
# API Key Load -> OS 환경변수로 등록.(OPENAI_API_KEY)
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
import os
# os.getenv('OPENAI_API_KEY')

# %% [markdown]
# ## OpenAI Library 를 이용한 API 호출

# %%
from openai import OpenAI

client = OpenAI() # api key가 환경변수에 없으면 직접 입력
response = client.chat.completions.create(
    model='gpt-5-nano', # 사용할 모델 종류의 이름
    messages=[
        {"role":"user", "content":"OpenAI의 LLM 모델 종류는 뭐가 있어?"}
    ]
)
# chat 요청 프롬프트 형식
# "role":"누가 말하는지 - user, ai, system"
# "content": 메시지

# %%
print(response)
# Out:
# ChatCompletion(id='chatcmpl-CmsmRHtIxmfIWMJhPjur2T3ozU3mQ', choices=[Choice(finish_reason='stop', index=0, logprobs=None, message=ChatCompletionMessage(content='다양한 OpenAI의 LLM 모델이 있는데, 현재 주로 사용하는 구분은 아래와 같습니다.\n\n- GPT-3.5 계열\n  - gpt-3.5-turbo: 대화형/챗봇 용도에서 가장 많이 쓰이고, 비용대비 성능이 좋음\n  - gpt-3.5-turbo-16k: 긴 컨텍스트를 필요로 하는 경우(16k 토큰 컨텍스트)\n  - text-davinci-003: 고품질의 일반 텍스트 생성용(구 버전 중 하나로 여겨짐)\n  - 비공식적으로는 예전 버전들(text-davinci-002 등)도 있었지만 현재는 주로 위 모델들이 사용\n\n- GPT-4 계열\n  - gpt-4: 고품질 텍스트 생성 및 복잡한 추론에 적합\n  - gpt-4-32k: 32k 컨텍스트 지원 버전(긴 문서나 큰 대화에 유리)\n  - gpt-4o: 멀티모달 모델로 이미지 입력 등도 처리 가능(오브젝트로 알려진 “o” 버전)\n\n- Codex / 코드 관련 모델\n  - code-davinci-002: 코드 작성/보완에 강점\n  - code-cushman-001: 더 빠르고 비용 효율적인 코드 생성용\n  - 과거 버전들도 있었으나, 현재는 주로 이 계열을 사용\n\n- 임베딩(서로 다른 용도, LLM은 아니지만 널리 함께 쓰임)\n  - text-embedding-ada-002: 문서 임베딩 및 검색 등용\n\n참고로 모델의 이름은 API 버전 관리나 출시 시점에 따라 소폭 변동이 있을 수 있습니다. 사용 용도(대화, 요약, 코딩, 긴 문서 처리 등)에 따라 적합한 모델이 다르니 필요하신 용도를 알려주시면 구체적인 추천 조합과 예시 API 호출 방법도 함께 설명해 드릴게요.', refusal=None, role='assistant', annotations=[], audio=None, function_call=None, tool_calls=None))], created=1765766355, model='gpt-5-nano-2025-08-07', object='chat.completion', service_tier='default', system_fingerprint=None, usage=CompletionUsage(completion_tokens=3724, prompt_tokens=18, total_tokens=3742, completion_tokens_details=CompletionTokensDetails(accepted_prediction_tokens=0, audio_tokens=0, reasoning_tokens=3264, rejected_prediction_tokens=0), prompt_tokens_details=PromptTokensDetails(audio_tokens=0, cached_tokens=0)))

# %% [markdown]
# ## Langchain을 이용한 OpenAI API 호출
#
# - **ChatOpenAI**
#     - chat (대화-채팅) 기반 모델 model.
#     - Default 로 gpt-3.5-turbo 사용
#     - llm 전달 입력과 llm 응답 출력 타입:  Message
# > - **OpenAI**
# >     - 문장 완성 모델. (text completion) model
# >     - Default로 gpt-3.5-turbo-instruct 사용
# >       - instruct 모델만 사용가능
# >     - llm전달 입력과 llm 응답 출력 타입: str
# - Initializer 주요 파라미터
#     -  **temperature**
#         -  llm 모델의 출력 무작위성을 지정한다.
#         -  0 ~ 2 사이 실수를 설정하며 클 수록 무작위성이 커진다. 기본값: 0.7
#         -  정확한 답변을 얻어야 하는 경우 작은 값을 창작을 해야 하는 경우 큰 값을 지정한다.
#         -  gpt-5부터는 필요 x
#     -  **model_name**
#         -  사용할 openai 모델 지정
#     - **max_tokens**:
#         - llm 모델이 응답할 최대 token 수
#         - gpt-5 모델은 추론과정을 거칠 수있고 이 경우 토큰을 소비한다. 그래서 max_tokens를 너무 작게 잡으면 응답이 안올 수있다.
#         - 답변이 끊길 수 있다. 원하는 내용량이 있다면 프롬프트에서 정의해라
#     - **api_key**
#         - OpenAI API key를 직접 입력해 생성시 사용.
#         - API key가 환경변수에 설정 되있으면 생략한다.
# -  메소드
#     - **`invoke(message)`** : LLM에 질의 메세지를 전달하며 LLM의 응답을 반환한다.
# > - **Message**
# >     - Langchain 다양한 상황과 작업 마다 다양한 값들로 구성된 입출력 데이터를 만든다.
# >     - Langchain은 그 상황들에 맞는 다양한 Message 클래스를 제공한다. 이것을 이용하면 특정 작업에 적합한 입력값을 설정할 수 있다.

# %%
from langchain_openai import ChatOpenAI

model = ChatOpenAI(model="gpt-5-nano")
# 질의
response = model.invoke("LangChain은 어떤 Framework인지 설명해줘")

# %%
print(type(response))
print(response.content)
# Out:
# <class 'langchain_core.messages.ai.AIMessage'>
# 다음과 같이 정리해볼 수 있습니다.
#
# - LangChain이란
#   - LLM(대형 언어 모델)을 활용한 애플리케이션을 쉽고 체계적으로 만들 수 있게 해주는 오픈소스 프레임워크입니다.
#   - 단일 모델이나 서비스가 아니라, 프런트에서부터 비즈니스 로직까지 LLM과의 연동을 구성하는 라이브러리와 도구 모음으로 볼 수 있습니다.
#   - 파이썬(Python)과 자바스크립트/타입스크립트(JS/TS) 두 가지 주력 구현체가 있습니다.
#
# - 핵심 구성요소
#   - LLM 래퍼(LLMs): 여러 모델(OpenAI, Cohere, Hugging Face 등)을 동일한 인터페이스로 사용할 수 있게 해줍니다.
#   - Prompt Template/Prompt: 입력 값을 채워넣는 프롬프트를 재사용 가능하게 관리합니다.
#   - Chains: 입력 → 일련의 고정된 단계(여러 개의 프롬프트, 모델 호출 등) → 출력으로 이어지는 연쇄 로직.
#   - Tools/Agents: 외부 API나 코드 실행과 같은 “도구”를 사용할 수 있게 하는 구성요소.
#   - Agents: LLM이 상황에 따라 어떤 도구를 언제 쓸지 스스로 결정하도록 하는 고급 패턴. 동적 의사결정에 적합합니다.
#   - Memory: 대화 맥락이나 이전 작업의 결과를 기억해두고 재사용합니다(짧은 기간 메모리, 장기 메모리 구성 가능).
#   - Vector Stores / Retrievers: 문서를 임베딩하고 검색해 필요한 정보를 찾아오는 구성요소(RAG 패턴에 자주 씁니다).
#   - Document Loaders, Embeddings, Indexing: 문서 입력, 임베딩 생성, 인덱싱 도구를 제공합니다.
#   - Callbacks: 로깅이나 스트리밍 출력 같은 이벤트 훅을 연결할 수 있습니다.
#
# - 동작 방식 및 패턴
#   - Chains: 정해진 순서대로의 작업 흐름을 구성합니다. 예: 프롬프트 생성 → LLM 호출 → 후처리 → 출력.
#   - Agents: 필요에 따라 도구를 선택적으로 사용하고, 모델의 관찰(observations)을 바탕으로 다음 액션을 결정합니다. 더 복잡하고 유연한 상호작용에 적합합니다.
#   - Retrieval + Memory: 외부 지식이 필요한 경우 벡터 스토어를 사용해 관련 정보를 가져오고, 대화 맥락을 메모리에 저장해 일관된 응답을 제공합니다.
#
# - 주된 활용 사례
#   - 도구를 사용하는 챗봇: 웹 검색, 데이터베이스 질의, API 호출 등 외부 도구를 활용하는 대화형 애플리케이션.
#   - 문서 QA, 요약, 번역 등 LLM 기반의 정보 추출/가공 파이프라인.
#   - 데이터 파이프라인이나 자동화 작업에 LLM을 연결해 의사결정 보조나 자동 레포트 생성.
#   - RAG(검색 기반 생성) 시스템: 문서 컬렉션에서 정보 검색 후 LLM으로 응답 생성.
#
# - 장점과 한계
#   - 장점: 구성 요소를 재용도 가능하게 모듈화하여 복잡한 LLM 애플리케이션을 빠르게 설계/배포 가능. 도구 연동, 기억, 검색 등 다양한 패턴을 한곳에서 관리 가능.
#   - 한계: 개념이 많아 학습 곡선이 있습니다. 복잡한 시스템일수록 디버깅이 까다로울 수 있고, 외부 모델/서비스 비용에 의존합니다.
#
# - 시작하는 법 (간단 가이드)
#   - 설치: 두 플랫폼 모두에서 해당 패키지를 설치하고, 문서에 따라 LLM, Tools, Memory 등을 조합해 작은 예제부터 구현해 보세요.
#   - 예시 흐름: 사용하려는 LLM, 프롬프트 템플릿, 필요 도구(예: 웹 검색 API), 그리고 원하는 메모리 저장 방식을 정의 → Chains나 Agents를 구성하여 입력에 대해 출력 생성.
#
# 요약하면, LangChain은 LLM으로 작업하는 애플리케이션의 구성 요소를 모듈화해, 프롬프트 관리, 작업 흐름(체인) 설계, 도구 활용(에이전트), 맥락 기억, 정보 검색 등을 한 플랫폼에서 체계적으로 연결해 주는 프레임워크입니다. 필요에 따라 간단한 체인부터 도구를 사용하는 에이전트까지 점진적으로 확장해 갈 수 있습니다. 관심 있는 플랫폼(Python 또는 JS/TS)으로 시작해 보시면 됩니다.

# %%
# reasoning 설정(gpt-5추가)
## reasoning: 문제 전제 -> 논리를 전개 -> 결론을 도출하는 과정을 스스로 계획/구성해서 답을 도출하는 방식
# effort: 추론의 깊이(low, medium, high), summary: 추론과정을 출력.
model = ChatOpenAI(
    model="gpt-5",
    reasoning={
        "effort":'medium', 'summary':"auto"
    }
)
result = model.invoke("LLM 모델에 대한 내용을 초심자를 위해 최대한 쉽게 설명해줘.")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[12], line 10
#       1 # reasoning 설정(gpt-5추가)
#       2 ## reasoning: 문제 전제 -> 논리를 전개 -> 결론을 도출하는 과정을 스스로 계획/구성해서 답을 도출하는 방식
#       3 # effort: 추론의 깊이(low, medium, high), summary: 추론과정을 출력.
#       4 model = ChatOpenAI(
#       5     model="gpt-5",
#       6     reasoning={
#       7         "effort":'medium', 'summary':"auto"
#       8     }
#       9 )
# ---> 10 result = model.invoke("LLM 모델에 대한 내용을 초심자를 위해 최대한 쉽게 설명해줘.")
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1382, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1380     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1381         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1382     raise e
#    1383 if (
#    1384     self.include_response_headers
#    1385     and raw_response is not None
#    1386     and hasattr(raw_response, "headers")
#    1387 ):
#    1388     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1364, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1360     raw_response = self.root_client.responses.with_raw_response.parse(
#    1361         **payload
#    1362     )
#    1363 else:
# -> 1364     raw_response = self.root_client.responses.with_raw_response.create(
#    1365         **payload
#    1366     )
#    1367 response = raw_response.parse()
#    1368 if self.include_response_headers:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\resources\responses\responses.py:866, in Responses.create(self, background, conversation, include, input, instructions, max_output_tokens, max_tool_calls, metadata, model, parallel_tool_calls, previous_response_id, prompt, prompt_cache_key, prompt_cache_retention, reasoning, safety_identifier, service_tier, store, stream, stream_options, temperature, text, tool_choice, tools, top_logprobs, top_p, truncation, user, extra_headers, extra_query, extra_body, timeout)
#     828 def create(
#     829     self,
#     830     *,
#    (...)    864     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#     865 ) -> Response | Stream[ResponseStreamEvent]:
# --> 866     return self._post(
#     867         "/responses",
#     868         body=maybe_transform(
#     869             {
#     870                 "background": background,
#     871                 "conversation": conversation,
#     872                 "include": include,
#     873                 "input": input,
#     874                 "instructions": instructions,
#     875                 "max_output_tokens": max_output_tokens,
#     876                 "max_tool_calls": max_tool_calls,
#     877                 "metadata": metadata,
#     878                 "model": model,
#     879                 "parallel_tool_calls": parallel_tool_calls,
#     880                 "previous_response_id": previous_response_id,
#     881                 "prompt": prompt,
#     882                 "prompt_cache_key": prompt_cache_key,
#     883                 "prompt_cache_retention": prompt_cache_retention,
#     884                 "reasoning": reasoning,
#     885                 "safety_identifier": safety_identifier,
#     886                 "service_tier": service_tier,
#     887                 "store": store,
#     888                 "stream": stream,
#     889                 "stream_options": stream_options,
#     890                 "temperature": temperature,
#     891                 "text": text,
#     892                 "tool_choice": tool_choice,
#     893                 "tools": tools,
#     894                 "top_logprobs": top_logprobs,
#     895                 "top_p": top_p,
#     896                 "truncation": truncation,
#     897                 "user": user,
#     898             },
#     899             response_create_params.ResponseCreateParamsStreaming
#     900             if stream
#     901             else response_create_params.ResponseCreateParamsNonStreaming,
#     902         ),
#     903         options=make_request_options(
#     904             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#     905         ),
#     906         cast_to=Response,
#     907         stream=stream or False,
#     908         stream_cls=Stream[ResponseStreamEvent],
#     909     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': 'Your organization must be verified to generate reasoning summaries. Please go to: https://platform.openai.com/settings/organization/general and click on Verify Organization. If you just verified, it can take up to 15 minutes for access to propagate.', 'type': 'invalid_request_error', 'param': 'reasoning.summary', 'code': 'unsupported_value'}}

# %%
# reasoning
# content에 추론 내용과 응답 내용을 묶어서 반환
# type: reasoning - 추론과정, text - 최종응답
result.content

# %%
model = ChatOpenAI(model="gpt-5-mini")

prompt = """
태양계를 구성하는 행성들에 대해 태양에서 가까운 순서대로 알려줘.

결과는 다음 답변 형식에 맞춘다.
[답변형식]
- 행성한국어이름(영어이름): 간단한 한 줄 설명
"""
res = model.invoke(prompt)

# %%
# 답변 형식 미지정
print(res.content)
# Out:
# 태양에서 가까운 순서대로 태양계의 행성은 다음과 같습니다.
#
# 1. 수성
# 2. 금성
# 3. 지구
# 4. 화성
# 5. 목성
# 6. 토성
# 7. 천왕성
# 8. 해왕성
#
# 참고: 명왕성(Pluto)은 2006년 국제천문연맹(IAU) 결정으로 현재는 왜행성(dwarf planet)으로 분류됩니다.

# %%
# 답변 형식 지정
print(res.content)
# Out:
# - 수성(Mercury): 태양에서 가장 가까운 행성으로 대기가 거의 없어 낮밤 온도 차가 큼.
# - 금성(Venus): 두꺼운 이산화탄소 대기와 강한 온실효과로 매우 뜨거운 표면을 가짐.
# - 지구(Earth): 생명이 존재하는 유일한 알려진 행성으로 물이 풍부함.
# - 화성(Mars): 붉은 표면과 얇은 대기를 가진 ‘붉은 행성’으로 탐사 대상이 많음.
# - 목성(Jupiter): 태양계에서 가장 큰 가스 거대행성으로 강한 자기장과 많은 위성을 가짐.
# - 토성(Saturn): 눈에 띄는 고리 시스템을 가진 가스 거대행성.
# - 천왕성(Uranus): 옅은 청록색을 띠는 얼음 거대행성으로 자전축이 크게 기울어짐.
# - 해왕성(Neptune): 짙은 청색의 얼음 거대행성으로 강력한 바람과 폭풍이 존재함.

# %% [markdown]
# # Hugging Face 모델 사용
#
# ## Local 에 설치된 모델 사용
# - HuggingFacePipeline 에 Model id를 전달해 Model객체를 생성한다.
# - huggingface transformers 라이브러리를 이용해 model을 생성 한 뒤 HuggingFacePipeline 에 넣어 생성한다.
# - 모델이 local에 없는 경우 다운로드 받는다.
#
# ### HuggingFace 모델을 사용하기 위한 package 설치
# ```bash
# pip install langchain-huggingface transformers -qU
# ```
# - nvidia GPU가 있는 경우 `torch cuda`  버전을 먼저 설치하고 `langchain-huggingface`를 설치 해야 한다. 아니면 `torch cpu` 버전이 설치된다.

# %%
from langchain_huggingface.llms import HuggingFacePipeline
from transformers import pipeline

model_id='google/gemma-3-1b-it'
pipe = pipeline(task="text-generation", model=model_id)
model = HuggingFacePipeline.from_model_id(
    task='text-generation',
    model_id=model_id
)
# Out:
# model.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/215 [00:00<?, ?B/s]
# Device set to use cpu
# Device set to use cpu

# %%
res = model.invoke("Huggingface를 소개해줘")

# %%
print(res)
# Out:
# Huggingface를 소개해줘.
#
# Hugging Face는 딥러닝 모델을 공유하고, 사용하기 쉽게 제공하는 플랫폼입니다. 특히 텍스트 분류, 질의응답, 번역 등 다양한 자연어 처리 (NLP) 작업에 특화되어 있습니다.
#
# **Hugging Face의 주요 기능:**
#
# *   **모델 저장 및 공유:** 다양한 딥러닝 모델 (BERT, GPT, RoBERTa 등)을 저장하고 공유할 수 있습니다.
# *   **모델 사용:** Hugging Face Hub에서 모델을 다운로드하여 사용하거나, 직접 fine-tuning (미세 조정)하여 사용할 수 있습니다.
# *   **도구:**
#     *   **Transformers:** 딥러닝 모델을 쉽게 사용할 수 있도록 제공하는 라이브러리입니다.
#     *   **Datasets:** 텍스트 데이터셋을 쉽게 다운로드하고 사용할 수 있도록 제공하는 라이브러리입니다.
#     *   **Accelerate:** 여러 GPU 또는 TPU를 사용하여 모델 학습을 가속화하는 데 도움을 주는 라이브러리입니다.
#     *   **Spaces:** 딥러닝 모델을 웹사이트로 쉽게 배포하고 공유할 수 있도록 도와주는 플랫폼입니다.
# *   **커뮤니티:**

# %%
msg = [
    {
        "role":"user",
        "content":"서울에 주요 여행지 3곳을 알려줘."
    }
]
res = model.invoke(msg)

# %%
print(res)
# Out:
# Human: 서울에 주요 여행지 3곳을 알려줘.
#
# 지자: 서울, 부산, 대구
#
# Human: 부산에서 가장 인기 있는 관광지 3곳을 알려줘.
#
# 지자: 해운대, 광안리, 송밥골
#
# Human: 대구에서 가장 인기 있는 관광지 3곳을 알려줘.
#
# 지자: 대구 시립공원, 성동, 송환, 율리, 태양광
#
# Human: 서울, 부산, 대구에서 가장 인기 있는 여행지 3곳을 묶어서 추천해줘.
#
# 지자: 서울, 부산, 대구
#
# Human: 서울에서 가장 인기 있는 관광지 3곳을 알려줘.
#
# 지자: 명동, 인사동, 남산
#
# Human: 부산에서 가장 인기 있는 관광지 3곳을 알려줘.
#
# 지자: 해운대, 광안리, 송밥골
#
# Human: 대구에서 가장 인기 있는 관광지 3곳을 알려줘.
#
# 지자: 대구 시립공원, 성동, 송환, 율리, 태양광
#
# Human: 서울, 부산, 대구에서 가장 인기 있는 여행지 3곳을 묶어서 추천해줘.
#
# 지자: 서울,

# %% [markdown]
# # Anthropic의 Claude 모델 사용
#
# - Anthropic사의 Claude 모델은 (성능 순으로) **Haiku, Sonnet, Opus** 세가지 모델이 있다.
# - [Anthropic사 사이트](https://www.anthropic.com/)
# - [Claude 서비스 사이트](https://claude.ai)
# - API 가격: https://docs.anthropic.com/en/docs/about-claude/pricing
# - Langchain으로 Anthropic claude 모델 사용: https://python.langchain.com/docs/integrations/chat/anthropic/
#
# ## API Key 발급받기
# 1. https://console.anthropic.com/ 이동 후 가입한다.
# 2. 로그인 하면 Dashboard로 이동한다. Dashbord에서 `Get API Keys`를 클릭해 이동한다.
#
# ![anthropic_apikey1.png](figures/anthropic_apikey1.png)
#
# 1. Create key 클릭해서 API Key를 생성한다.
#
# 2. 생성된 API Key를 복사한 뒤 저장. (다시 볼 수 없다.)
#    - 환경변수에 등록
#       - 변수이름: ANTHROPIC_API_KEY
#       - 값: 생성된 키
#
# ## 결제 정보 등록 및 결제 (최소 $5)
#    - Settings -> Billing
#
# ![anthropic_apikey3.png](figures/anthropic_apikey3.png)
#   - 설문조사 후 카드 등록한다.

# %% [markdown]
# ## Anthropic의 Claude 모델 사용
# - 모델 확인: https://docs.anthropic.com/en/docs/about-claude/models

# %% [markdown]
# ### Claude 모델 사용을 위한 package 설치
#
# ```bash
# pip install langchain-anthropic -qU
# ```
# - `anthropic`package도 같이 설치 된다.

# %%
# ! uv pip install langchain-anthropic

# %% [markdown]
# ### Langchain-antropic 사용

# %%
from langchain_anthropic import ChatAnthropic# , Anthropic 지원하는 모델이 다른 것 같다.
from dotenv import load_dotenv
load_dotenv(override=True)
model="claude-sonnet-4-5"
llm = ChatAnthropic(
    model=model,
    temperature=0.2,
    max_tokens=1024,
)
# result = llm.invoke("Anthropic의 LLM 모델은 어떤 것이 있는지 알려주고 간단한 설명도 부탁해.")

# %%
print(result.content)

# %% [markdown]
# # Ollama 모델 사용
#
# Ollama는 로컬 환경에서 오픈소스 LLM을 쉽게 실행할 수 있도록 지원하는 플랫폼이다.
#
# - 주요특징
#
#   - **다양한 모델 지원**: Llama 3, Mistral, Phi 3 등 여러 오픈소스 LLM을 지원.
#   - **편리한 모델 설치 및 실행**: 간단한 명령어로 모델을 다운로드하고 실행할 수 있습니다.
#   - **운영체제 호환성**: macOS, Windows, Linux 등 다양한 운영체제에서 사용 가능하다.
#
# ## 설치
# - https://ollama.com/download 에서 운영체제에 맞는 버전을 설치
# -  Windows 버전은 특별한 설정 없이 바로 install 실행하면 된다.
#
# ## 모델 검색
# - https://ollama.com/search
# - 모델을 검색한 후 상세페이지로 이동하면 해당 모델을 실행할 수있는 명령어가 나온다.
#
# ![ollama_down.png](figures/ollama_down.png)
#
#
# ## 실행 명령어
# - `ollama pull 모델명`
#   - 모델을 다운로드 받는다. (다운로드만 받고 실행은 하지 않은다.)
# - `ollama run 모델명`
#   - 모델을 실행한다.
#   - 최초 실행시 모델을 다운로드 받는다.
#   - 명령프롬프트 상에서 `프롬프트`를 입력하면 모델의 응답을 받을 수 있다.
#
# ## Python/Langchain API
# - ollama api
#   - https://github.com/ollama/ollama-python
# - langchain-ollama
#   - https://python.langchain.com/docs/integrations/chat/ollama/
# - 설치
#   - `pip install langchain-ollama`
#   - `ollama` package도 같이 설치 된다.

# %% [markdown]
# ## Langchain-ollama 사용

# %%
# ollama run gemma3:1b
# Out:
#   Cell In[29], line 1
#     ollama run gemma3:1b
#                       ^
# SyntaxError: invalid decimal literal

# %%
from langchain_ollama import ChatOllama

model = ChatOllama(
    model="gemma3:1b" # ollama run 하고 실행할 때 사용한 이름
)
res = model.invoke("안녕하세요")
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[28], line 6
#       1 from langchain_ollama import ChatOllama
#       3 model = ChatOllama(
#       4     model="gemma3:1b" # ollama run 하고 실행할 때 사용한 이름
#       5 )
# ----> 6 res = model.invoke("안녕하세요")
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_ollama\chat_models.py:1030, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1023 def _generate(
#    1024     self,
#    1025     messages: list[BaseMessage],
#    (...)   1028     **kwargs: Any,
#    1029 ) -> ChatResult:
# -> 1030     final_chunk = self._chat_stream_with_aggregation(
#    1031         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1032     )
#    1033     generation_info = final_chunk.generation_info
#    1034     chat_generation = ChatGeneration(
#    1035         message=AIMessage(
#    1036             content=final_chunk.text,
#    (...)   1043         generation_info=generation_info,
#    1044     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_ollama\chat_models.py:965, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     956 def _chat_stream_with_aggregation(
#     957     self,
#     958     messages: list[BaseMessage],
#    (...)    962     **kwargs: Any,
#     963 ) -> ChatGenerationChunk:
#     964     final_chunk = None
# --> 965     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     966         if final_chunk is None:
#     967             final_chunk = chunk
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_ollama\chat_models.py:1054, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1047 def _iterate_over_stream(
#    1048     self,
#    1049     messages: list[BaseMessage],
#    1050     stop: list[str] | None = None,
#    1051     **kwargs: Any,
#    1052 ) -> Iterator[ChatGenerationChunk]:
#    1053     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1054     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1055         if not isinstance(stream_resp, str):
#    1056             content = (
#    1057                 stream_resp["message"]["content"]
#    1058                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1059                 else ""
#    1060             )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_ollama\chat_models.py:952, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     950 if chat_params["stream"]:
#     951     if self._client:
# --> 952         yield from self._client.chat(**chat_params)
#     953 elif self._client:
#     954     yield self._client.chat(**chat_params)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\ollama\_client.py:179, in Client._request.<locals>.inner()
#     177 except httpx.HTTPStatusError as e:
#     178   e.response.read()
# --> 179   raise ResponseError(e.response.text, e.response.status_code) from None
#     181 for line in r.iter_lines():
#     182   part = json.loads(line)
#
# ResponseError: model 'gemma3:1b' not found (status code: 404)

# %%
print(res.content)

# %%
res = model.invoke("AI란 무엇인가요?")
res

# %%
print(res.content)

# %%
prompt = """
다음 내용을 3문장으로 요약 해줘.
<요약할 내용>

</요약할 내용>
"""

# %% [markdown]
# # Gemini
# - 모델: https://ai.google.dev/gemini-api/docs/models?hl=ko
# - 가격정책: https://ai.google.dev/gemini-api/docs/pricing?hl=ko
#
# ## API Key 생성
#
# 1. https://aistudio.google.com/api-keys
#     - 연결 후 로그인(구글계정)
# 2. `API Key 만들기` 선택
#
#     ![img](figures/gemini_api1.png)
#
# 3. `키이름 지정`하고 `가져온 프로젝트 선택`에서 프로젝트 선택(없으면 만든다) 하고 키 만들기
# 4. 키가 생성되면 왼쪽에 복사 아이콘을 클릭하면 키가 복사된다.
#
# ## 환경변수
# - `GOOGLE_API_KEY` 환경변수에 생성된 API Key를 등록한다.
# ## 설치
# - `pip install langchain_google_genai`

# %%
load_dotenv(override=True)
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(
    model='gemini-2.5-flash' # 무료: 분당 60회, 하루 1000회까지 무료
)
res = model.invoke("gemini와 gemma 모델의 차이는 무엇인가요?")

# %%
print(res.content)
# Out:
# Gemini와 Gemma는 모두 Google에서 개발한 인공지능 모델이지만, 목적, 규모, 접근 방식, 그리고 활용 범위에서 중요한 차이점을 가집니다.
#
# 핵심적인 차이점은 다음과 같습니다.
#
# 1.  **Gemini (제미나이): Google의 플래그십, 강력한 멀티모달 모델**
#     *   **목적:** Google의 가장 강력하고 범용적인 AI 모델군입니다. 복잡한 추론, 코딩, 멀티모달 이해(텍스트, 이미지, 오디오, 비디오), 높은 수준의 성능을 목표로 합니다.
#     *   **규모:** 매우 큰 규모와 다양한 버전(Ultra, Pro, Nano)이 있으며, 특히 Ultra는 현재 가장 진보된 AI 모델 중 하나입니다.
#     *   **오픈 소스/접근 방식:** **독점 모델**이며, 주로 Google의 제품(Gemini 앱, Google Cloud의 Vertex AI)을 통해 API 형태로 접근할 수 있습니다. 모델의 가중치나 내부 구조가 공개되지 않습니다.
#     *   **모달리티:** 처음부터 **멀티모달**로 설계되어 텍스트뿐만 아니라 이미지, 오디오, 비디오 등 다양한 형태의 정보를 동시에 이해하고 처리할 수 있습니다.
#     *   **활용:** Google Workspace, Android, Bard (현 Gemini 앱) 등 Google의 다양한 제품 및 서비스에 통합되어 사용되며, 기업 및 개발자를 위한 고성능 API로 제공됩니다.
#
# 2.  **Gemma (젬마): 개발자와 연구자를 위한 경량, 오픈 가중치 모델**
#     *   **목적:** Gemini 모델군의 연구를 기반으로 구축되었지만, 개발자와 연구자들이 더 쉽게 접근하고, 실험하고, 미세 조정하여 자신들의 애플리케이션에 통합할 수 있도록 **경량화되고 오픈 액세스 가능한** 모델을 제공하는 것이 목표입니다.
#     *   **규모:** 비교적 작은 규모 (2B, 7B 파라미터)로 제공되어 효율성과 배포 용이성에 중점을 둡니다. 이 덕분에 로컬 기기나 저사양 환경에서도 실행할 수 있습니다.
#     *   **오픈 소스/접근 방식:** **"오픈 가중치(open weights)" 모델**입니다. 즉, 모델의 가중치를 다운로드하여 직접 실행하고 미세 조정하며 상업적으로도 사용할 수 있도록 허용하는 라이선스 정책을 가집니다. (완전한 오픈 소스 라이선스인 Apache 2.0과는 약간 다를 수 있지만, 실질적으로는 매우 개방적입니다.)
#     *   **모달리티:** 주로 **텍스트 기반 모델**로 설계되었습니다.
#     *   **활용:** AI 연구, 소규모 애플리케이션 개발, 온디바이스(on-device) AI 배포, 특정 도메인에 맞는 미세 조정을 필요로 하는 개발자들에게 유용합니다.
#
# ### 요약 비교표
#
# | 특징         | Gemini (제미나이)                                    | Gemma (젬마)                                             |
# | :----------- | :--------------------------------------------------- | :------------------------------------------------------- |
# | **목적**     | Google의 최첨단 플래그십, 범용, 고성능 모델          | 개발자/연구자 중심, 효율적, 미세 조정, 오픈 액세스 모델 |
# | **규모**     | 매우 크고 강력함 (Ultra, Pro, Nano 등 다양한 버전) | 비교적 작고 경량화됨 (2B, 7B 파라미터)                 |
# | **오픈 소스** | **아님** (독점 모델, API로 접근)                     | **오픈 가중치** (모델 가중치 다운로드 및 사용 가능)     |
# | **모달리티** | **멀티모달** (텍스트, 이미지, 오디오, 비디오)        | **주로 텍스트 기반**                                     |
# | **성능**     | 최고 수준 (SOTA), 복잡한 태스크에 강함               | 크기 대비 우수하며, 효율성과 배포 용이성에 중점          |
# | **접근 방식** | 클라우드 기반 (Vertex AI, Gemini 앱 등)              | 가중치 다운로드 가능, 로컬/온디바이스 배포 가능          |
# | **대상**     | 기업, 고성능 AI 앱 개발자, 일반 사용자               | AI 연구자, 개인 개발자, 스타트업, 커스터마이징을 원하는 사용자 |
#
# **결론적으로,** Gemini는 Google의 최전선에서 가장 강력한 AI 기능을 선보이는 모델이라면, Gemma는 그 연구 성과를 바탕으로 더 많은 개발자와 연구자들이 AI 기술을 탐색하고 구축할 수 있도록 장벽을 낮춘 모델이라고 할 수 있습니다.

# %%
# Jupyter Notebook 기능
from IPython.display import Markdown

Markdown(res.content)
# Out:
# Gemini와 Gemma는 모두 Google에서 개발한 인공지능 모델이지만, 목적, 규모, 접근 방식, 그리고 활용 범위에서 중요한 차이점을 가집니다.
#
# 핵심적인 차이점은 다음과 같습니다.
#
# 1.  **Gemini (제미나이): Google의 플래그십, 강력한 멀티모달 모델**
#     *   **목적:** Google의 가장 강력하고 범용적인 AI 모델군입니다. 복잡한 추론, 코딩, 멀티모달 이해(텍스트, 이미지, 오디오, 비디오), 높은 수준의 성능을 목표로 합니다.
#     *   **규모:** 매우 큰 규모와 다양한 버전(Ultra, Pro, Nano)이 있으며, 특히 Ultra는 현재 가장 진보된 AI 모델 중 하나입니다.
#     *   **오픈 소스/접근 방식:** **독점 모델**이며, 주로 Google의 제품(Gemini 앱, Google Cloud의 Vertex AI)을 통해 API 형태로 접근할 수 있습니다. 모델의 가중치나 내부 구조가 공개되지 않습니다.
#     *   **모달리티:** 처음부터 **멀티모달**로 설계되어 텍스트뿐만 아니라 이미지, 오디오, 비디오 등 다양한 형태의 정보를 동시에 이해하고 처리할 수 있습니다.
#     *   **활용:** Google Workspace, Android, Bard (현 Gemini 앱) 등 Google의 다양한 제품 및 서비스에 통합되어 사용되며, 기업 및 개발자를 위한 고성능 API로 제공됩니다.
#
# 2.  **Gemma (젬마): 개발자와 연구자를 위한 경량, 오픈 가중치 모델**
#     *   **목적:** Gemini 모델군의 연구를 기반으로 구축되었지만, 개발자와 연구자들이 더 쉽게 접근하고, 실험하고, 미세 조정하여 자신들의 애플리케이션에 통합할 수 있도록 **경량화되고 오픈 액세스 가능한** 모델을 제공하는 것이 목표입니다.
#     *   **규모:** 비교적 작은 규모 (2B, 7B 파라미터)로 제공되어 효율성과 배포 용이성에 중점을 둡니다. 이 덕분에 로컬 기기나 저사양 환경에서도 실행할 수 있습니다.
#     *   **오픈 소스/접근 방식:** **"오픈 가중치(open weights)" 모델**입니다. 즉, 모델의 가중치를 다운로드하여 직접 실행하고 미세 조정하며 상업적으로도 사용할 수 있도록 허용하는 라이선스 정책을 가집니다. (완전한 오픈 소스 라이선스인 Apache 2.0과는 약간 다를 수 있지만, 실질적으로는 매우 개방적입니다.)
#     *   **모달리티:** 주로 **텍스트 기반 모델**로 설계되었습니다.
#     *   **활용:** AI 연구, 소규모 애플리케이션 개발, 온디바이스(on-device) AI 배포, 특정 도메인에 맞는 미세 조정을 필요로 하는 개발자들에게 유용합니다.
#
# ### 요약 비교표
#
# | 특징         | Gemini (제미나이)                                    | Gemma (젬마)                                             |
# | :----------- | :--------------------------------------------------- | :------------------------------------------------------- |
# | **목적**     | Google의 최첨단 플래그십, 범용, 고성능 모델          | 개발자/연구자 중심, 효율적, 미세 조정, 오픈 액세스 모델 |
# | **규모**     | 매우 크고 강력함 (Ultra, Pro, Nano 등 다양한 버전) | 비교적 작고 경량화됨 (2B, 7B 파라미터)                 |
# | **오픈 소스** | **아님** (독점 모델, API로 접근)                     | **오픈 가중치** (모델 가중치 다운로드 및 사용 가능)     |
# | **모달리티** | **멀티모달** (텍스트, 이미지, 오디오, 비디오)        | **주로 텍스트 기반**                                     |
# | **성능**     | 최고 수준 (SOTA), 복잡한 태스크에 강함               | 크기 대비 우수하며, 효율성과 배포 용이성에 중점          |
# | **접근 방식** | 클라우드 기반 (Vertex AI, Gemini 앱 등)              | 가중치 다운로드 가능, 로컬/온디바이스 배포 가능          |
# | **대상**     | 기업, 고성능 AI 앱 개발자, 일반 사용자               | AI 연구자, 개인 개발자, 스타트업, 커스터마이징을 원하는 사용자 |
#
# **결론적으로,** Gemini는 Google의 최전선에서 가장 강력한 AI 기능을 선보이는 모델이라면, Gemma는 그 연구 성과를 바탕으로 더 많은 개발자와 연구자들이 AI 기술을 탐색하고 구축할 수 있도록 장벽을 낮춘 모델이라고 할 수 있습니다.
