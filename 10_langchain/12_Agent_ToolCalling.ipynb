# %% [markdown]
# # Agent 개요
# > **Agent는 대형 언어 모델을 두뇌로 사용하여, 목표를 스스로 이해하고 외부 도구와 상호작용하며 실제 작업을 자율적으로 수행하는 지능형 인공지능 시스템이다.**
#
# - Agent는 **대형 언어 모델(LLM, Large Language Model)과 다양한 도구(Tool)를 결합하여, 사용자의 복잡한 요청을 스스로 분석하고 처리하도록 설계된 지능형 인공지능 시스템이다.**
# 기존의 단순한 챗봇이 “질문 → 답변” 구조로 동작한다면,
#   - Agent는 **목표 설정 → 판단 → 실행 → 결과 반영**의 전 과정을 스스로 수행하는 구조를 가진다.
#
# - Agent는 주어진 목표를 달성하기 위해 자율적으로 **외부 환경(도구, API, 데이터베이스, 파일 시스템 등)과 상호작용하며 의사 결정을 내리고 실제 행동을 수행한다.**
# 이때 Agent의 **핵심적인 의사 결정과 추론 과정은 대형 언어 모델(LLM)이 담당**하며, **사람의 개입은 최소화**한다.
#
# - 즉, Agent는 단순히 정보를 말해주는 존재가 아니라, **"문제를 이해하고, 해결 방법을 계획하고, 직접 실행까지 담당하는 인공지능 작업 수행자"이다.**
#
# - AI 시스템을 구현할 때, **워크플로우**(**Workflow**)는 사전에 정의된 절차에 따라 실행 단계가 고정적인 구현 방식이라면, **에이전트**(**Agent**)는 주어진 목표를 달성하기 위해 스스로 계획을 수립하고, 상황을 판단하여 행동을 결정·실행하는 자율적인 방식이다.
#
#
#
# ## Agent의 주요 특징
#
# 1. **자율성** (Autonomy)
#    - Agent는 **사전 정의된 규칙**(Rule-based)에 의존하지 않고, LLM을 통해 현재 상황을 인지하고 추론하여 스스로 결정을 내리고 다음 행동을 계획할 수 있다.
#    - 즉, 사용자가 일일이 수행 단계를 지시하지 않아도, Agent는 **현재 상황을 해석하고 다음 행동을 동적으로 결정한다.**
#
# 2. **목표 지향성** (Goal-Oriented)
#     - Agent는 단순히 질문에 답변하는 **단순한 대화 상대가 아니라, 특정 목표와 복잡한 작업을 달성하기 위해 설계된 시스템**으로 최종 목표에 도달할 때 까지 반복적으로 행동한다.
#     - Agent는 어떤 처리를 할 때 항상 **"이 행동이 목표 달성에 도움이 되는가"를 기준**으로 판단한다.
#
# 3. **도구 활용** (Tool Utilization)
#     - Agent는 대형 언어 모델의 언어 이해 능력, 사전 학습 정보에만 의존하지 않고, 다양한 **외부 도구와 API를 함께 활용하여 실제 작업을 수행**한다.
#     - 이를 통해 LLM이 처리할 수없는 **최신 정보 검색, 복잡한 계산, 외부 시스템 제어**등과 같은 작업이 가능하다. 이를 통해 Agent는 **"말만 하는 AI"가 아니라 "실제로 일을 처리하는 AI"로 기능한다.**
#
# 4. **인간 개입 최소화** (Human-in-the-loop 최소화)
#     - Agent는 **문제 분석, 의사 결정, 행동 실행의 대부분을 스스로 결정하고 수행하도록 설계된다.**
#     - 사람은 **초기 목표 제시, 결과 확인 및 실행 최종 승인** 정도에 만 개입한다.

# %% [markdown]
# ## 다양한 Agent 활용 사례
#
# - **미국 국세청(IRS) 세무처리에 도입된 AI 에이전트**
#     - 미국 국세청(IRS)은 Salesforce Agentforce 기반 AI 에이전트를 도입해 세무 업무에서의 보조·분석 기능을 강화하고 업무 효율을 높이고 있다.
#
# -  **고객 추천 및 개인화된 콘텐츠 제공**
#     - Netflix, Amazon 같은 OTT 플랫폼은 사용자의 취향 변화에 따라 추천 시스템을 적응시키는 학습형 에이전트를 활용해 콘텐츠/제품 추천을 개선해 나간다.
#
# - **영업 지원용 AI 에이전트**
#     - Oracle은 영업 전문가를 위한 AI 에이전트를 도입해 고객 미팅 후 CRM 업데이트, 고객 데이터 분석·보고서 생성 같은 반복 작업을 자동화하고 있다.
#
# - **물류 최적화 및 배송 계획**
#     - Uber Freight, J.B. Hunt 등에서는 AI 에이전트를 활용해 실시간 교통·날씨 데이터 분석을 통해 가장 효율적인 배송 경로를 계산한다.
#
# - **AWS의 클라우드 자동화 에이전트**
#     - Amazon Web Services는 보안, DevOps, 일반 작업을 자동화하는 AI 에이전트들을 출시하며 클라우드 인프라 운영과 보안 모니터링을 강화하고 있다.
#
# - **삼성SDS AI 에이전트 플랫폼**
#     - 삼성SDS는 **사용자 개입 없이 스스로 판단·문제 해결이 가능한 AI 에이전트 플랫폼 ‘패브릭스(Fabrics)’**를 공개했다. 이를 통해 기업 내부에서 자동화된 의사결정과 작업 실행을 지원한다.

# %% [markdown]
# # ReAct 패턴
# - Agent 구현의 바탕이 되는 이론.
#
# ## 1. 개요
#
# ReAct는 **Reasoning**(추론)과 **Acting**(행동)을 결합한 AI Agent의 프롬프팅 패턴이다. 대형 언어 모델(LLM)이 단순히 답변을 생성하는 것이 아니라, 문제를 분석하고(Reasoning)하고 그에 따라 필요한 도구를 선택하여 실행하며(Acting), 결과를 관찰하고(Observation) 다음 추론에 반영하는 과정을 반복하면서 문제를 해결하는  Agent 설계 방식이다.
#
# ### ReAct의 핵심 개념
#
# 전통적인 프롬프팅 방식은 질문에 대해 즉시 답변을 생성한다. 하지만 **ReAct 패턴**은 다음과 같은 순환 구조를 따른다:
#
# ```
# 질문 → 생각(Thought) → 행동(Action) → 관찰(Observation) → 생각 → 행동 →  관찰 → ... → 답변
# ```
#
# - 예)
#   - 질문: "현재 서울의 날씨와 미세먼지 농도를 알려줘":
#
#     - **Thought(생각)**: 날씨 정보를 얻기 위해 날씨 API를 호출해야겠다
#     - **Action(행동)**: WeatherAPI.get_weather("서울")
#     - **Observation(관찰)**: 기온 15도, 맑음
#     - **Thought(생각)**: 이제 미세먼지 정보도 필요하다
#     - **Action(행동)**: AirQualityAPI.get_pm("서울")
#     - **Observation(관찰)**: PM10 농도 20㎍/㎥, 좋음
#     - **Answer(답변)**: 서울의 현재 날씨는 기온 15도로 맑고, 미세먼지 농도는 30㎍/㎥로 좋은 상태이다
#
# 이처럼 ReAct는 Agent가 **사고 과정을 명시적으로 드러내면서** 외부 도구를 활용하여 복잡한 문제를 해결할 수 있도록 한다.
#
# ### ReAct의 장점
#
# 1. **투명성**: Agent의 사고 과정을 추적할 수 있어 디버깅이 용이하다
# 2. **정확성**: 외부 지식과 도구를 활용하여 환각(hallucination)을 줄인다
# 3. **유연성**: 다양한 도구를 조합하여 복잡한 작업을 수행할 수 있다
# 4. **해석 가능성**: 각 단계의 추론 과정을 이해할 수 있다

# %% [markdown]
# ## 동작 단계
# ReAct 패턴은 크게 **5단계**의 순환 구조로 동작한다.
#
# 1. **질문 입력** (Question)
#      - 사용자로부터 해결해야 할 질문이나 작업을 입력받는다.
#      - 예시
#     ```bash
#      User Input: "2024년 노벨 물리학상 수상자는 누구이고, 그들의 주요 업적은 무엇인가?"
#     ```
#
# 2. **사고 단계** (Thought)
#      - 언어 모델이 사용자의 질문(요청)을 분석하고, 문제 해결을 위해 다음에 무엇을 해야 할지 추론한다.(계획을 세운다.)
#      - 이 단계에서 Agent는:
#          - 문제를 이해하고 분해한다
#          - 필요한 정보가 무엇인지 파악한다
#          - 어떤 도구를 사용해야 할지 결정한다
#          - 충분한 정보가 모였는지 판단한다
#
#        ```bash
#        Thought: 2024년 노벨 물리학상 정보는 내 학습 데이터에 없을 수 있다. 최신 정보를 검색해야 한다.
#        ```
#
# 3. **행동 단계** (Action)
#      - 사고 단계에서 결정된 계획을 바탕으로 실제 행동을 실행한다. 행동은 일반적으로 외부 도구(Tool) 호출한다.
#
#         ```bash
#         Action: 검색엔진.검색("2024 노벨 물리학상 수상자")
#         ```
#
# 4. **관찰 단계** (Observation)
#      - 행동(Acttion)의 결과를 관찰하고 얻은 정보를 확인한다.
#
#        ```bash
#        Observation: 2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다.
#        ```
#
#  5. **반복 또는 종료**
#        - 관찰한 정보가 사용자 질문에 대한 답변을 하는데 충분하지 않다면 2번의 사고 단계로 돌아가 추가 행동을 계획한다.(사고→행동→관찰 반복)
#        - 충분한 정보가 모였다면 그 정보를 바탕으로 최종 답변을 생성한다.
#
#           ```bash
#           Thought: 수상자 이름은 알았지만 구체적인 업적 내용이 필요하다.
#
#           Action: Search("John Hopfield Geoffrey Hinton 노벨상 업적")
#
#           Observation: Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신을 연구했다.
#
#           Thought: 이제 질문에 답할 충분한 정보가 모였다.
#
#           Action: Finish("2024년 노벨 물리학상은 John Hopfield와 Geoffrey Hinton에게 수여되었다. Hopfield는 연상 메모리를 위한 Hopfield 네트워크를 개발했고, Hinton은 딥러닝의 역전파 알고리즘과 볼츠만 머신 연구로 인공신경망 발전에 기여했다.")
#           ```
#
# ### 동작 흐름도
# ![ReAct](figures/agent-ReAct.png)

# %% [markdown]
# # TOOL
# - **Tool은 하나의 기능을 처리하는 함수이다.**
#     - Tool은 하나의 명확한 기능을 수행하도록 정의된 함수(Function) 형태의 외부 실행 수단이다.
#     - 대형 언어 모델(LLM)은 본래 텍스트를 생성하는 모델이므로, 실제 계산, 검색, 파일 처리, 데이터베이스 조회와 같은 현실 세계의 작업을 직접 수행할 수는 없다. 이런 실제 작업을 대신 수행하는 단위가 Tool 이다.
# - **AI Model은 Tool을 이용해 자체 지식의 한계(Knowlege cutoff)를 넘어서는 정보를 제공할 수 있다.**
# > **Knowledge Cutoff**:
# > - Knowledge cutoff는 AI 모델이 학습한 데이터가 마지막으로 업데이트된 시점을 의미하며, 그 이후에 발생한 정보나 사건에 대해서는 AI 모델이 학습한 지식으로는 알지 못하는 한계를 가지게 된다.
#
# ## Tool Calling 개요
# - **도구 호출**(Tool Calling)은 LLM이 자체적으로 수행할 수 없는 작업을 외부 도구나 API를 활용하여 처리할 수 있게 하는 핵심 기능이다. 이를 통해 **LLM은 자체 지식의 한계를 넘어서는 최신 정보, 정확한 계산, 외부 시스템 제어 등의 능력을 확보**할 수 있다.
#
# - **도구 호출(Tool Calling)의 3단계**
#     1. 도구 바인딩 (Tool Binding): **LLM에 사용가능한 tool들을 등록한다.**
#         - LLM에게 사용 가능한 도구 목록과 각 도구의 기능(설명) 및 필요한 입력 매개변수를 미리 정의하여 제공한다.
#             - Tool 함수
#             - Tool 이름
#             - Tool이 수행하는 기능 설명
#             - 입력 파라미터 type과 설명
#     2. **사용자 질의가 들어오면 LLM이 도구 사용 여부를 판단**한다.
#         - LLM 자체 추론으로 해결가능한 문제인지 Tool을 호출해야 처리할 수있는 문제 인지를 확인한다.
#         - **Tool 사용이 필요한 문제** 라고 판단하면
#           - 도구를 호출 하는 것이 아니라 어떻게 호출해야 하는지 요청정보를 생성한다.
#             - 어떤 Tool을 사용해야 하는지, 그 Tool에 어떤 값을 전달해야하는지를 응답으로 생성한다.
#     3.  **시스템이 Tool 호출 요청정보에 따라 Tool을 실행하고 그 결과를 LLM 에게 전달**한다.
#
#      ![toolcalling_concept](figures/toolcalling_concept.png)
#
# - **TOOL Calling 예**
#     - LLM이 수학 계산을 수행해야 할 때, 직접 계산하는 대신 미리 정의된 '계산' 도구를 호출하여 정확한 결과를 얻을 수 있다.
#   	- LLM에 최신 정보를 요청하는 질문이 들어왔을 때 '검색' 도구나 'Database 연동' 도구를 사용해 최신 뉴스를 검색하거나, 특정 데이터베이스에서 정보를 조회하는 등의 작업을 수행할 수 있다.
#   	- LLM 이 작성한 결과를 google docs와 같은 문서도구나 SNS에 등록한다.
#
# ## Langchain 과 Tool calling
# - Tool calling은 대부분의 LLM 서비스가 지원한다.
#   - [Tool Calling을 지원하는 LLM 모델](https://docs.langchain.com/oss/python/integrations/chat)만 사용할 수 있다.
# - LangChain은 다양한 모델들의 도구 호출 방식을 표준화하여 일관된 인터페이스로 제공한다. 이를 통해 개발자들은 다양한 모델과 도구들을 쉽게 통합할 수있다.
#   - [Langchain Tool Calling Concept](https://docs.langchain.com/oss/python/langchain/tools)
# - Langchain 제공 Built-in tools
#     -  https://docs.langchain.com/oss/python/integrations/tools

# %% [markdown]
# # LangChain Built-in Tools 사용으로 Tool Calling 이해
#
# - Langchain은 다양한 도구들을 미리 구현해서 제공하고 있다. 이것들을 builtin tool이라고 한다.
#   - [Langchain 지원 Built tools](https://docs.langchain.com/oss/python/integrations/tools)
# - Built-In tool 뿐만 아니라 사용자 정의 Tool들을 직접 구현할 수있는 방법도 제공한다.
#
# ## Tavily API 검색 Tool
# > Tavily 웹 검색 도구 사용해 Tool calling을 이해한다.
# - **Tavily** Service: AI을 위한 웹 검색 API Service.
# - https://tavily.com/
# -  LLM과 RAG 시스템에 최적화된 검색 엔진.
#    -  기존의 일반 검색 엔진들과 달리, Tavily는 AI 애플리케이션의 요구사항에 맞춰 설계되었다.
#    -  Tavily는 최대 20개 이상의 신뢰도 높은 웹사이트에서 관련정보를 수집한다.
#    -  수집된 데이터는 AI가 관련성, 신뢰도, 최신성 등을 기준으로 평가해 가장 적합한 정보만 선별해서 요약한다.
#    -  최종적으로 이 정보는 LLM이 바로 활용할 수있도록 컨텐츠 스티펫, 요약, 출처 등의 구조화된 형태로 반환한다.
#    -  월 1000회 무료 사용 가능.
# - **Tavily API Key 받기**
#   - 회원가입 후 로그인 한다.
#   - Overview 화면에서 API Key 생성
#     - default API key 사용할 수있다.
#   - 환경변수에 등록한다.
#       - 변수이름: `TAVILY_API_KEY`
#
# ### TavilySearch
# - Langchain에서 제공하는 tool로 Tavily 의 검색 엔진 API를 사용해 검색을 수행한다.
# - 설치
#   - `pip install langchain-tavily`
# - https://python.langchain.com/docs/integrations/tools/tavily_search/

# %%
from dotenv import load_dotenv
from langchain_tavily import TavilySearch # Tavily 검색 tool

load_dotenv()
# Out:
# c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "output_schema" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_tavily\tavily_research.py:97: UserWarning: Field name "stream" in "TavilyResearch" shadows an attribute in parent "BaseTool"
#   class TavilyResearch(BaseTool):  # type: ignore[override, override]
# True

# %%
# 객체 생성 - 검색 옵션을 파라미터로 설정.
tavily_search = TavilySearch(
    max_results=1,              # 최대 검색 개수,
    # include_raw_content=True,   # 원본 내용도 포함.
    # include_answer=True,        # 검색 결과 바탕으로 Tavily AI가 종합적 답변을 하도록 한다.
    # include_images=True,        # 검색한 문서 내의 이미지(경로)들을 반환
    # time_range="year",          # day, week, months, year - 현재 시점 기준으로 지정한 기간 내의 문서들만 검색 결과로 제공.
)
# 검색
query = "2025년 한국시리즈 우승팀은?"
# result = tavily_search.invoke(query)
result = tavily_search.invoke(
    {
        "query":query,
        "include_images":True # 옵션들을 key:value로 설정해서 실행 시 동적으로 적용
    }
)

# %%
print(type(result))
result
# Out:
# <class 'dict'>
# {'query': '2025년 한국시리즈 우승팀은?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': ['https://blogthumb.pstatic.net/MjAyNTAzMjNfNjYg/MDAxNzQyNzE4ODAxNzkw.oSUS641rn-u5mmRK9X90k3cOu6mV_S-lXEroFC41xc0g.ifwCdPWPHpTasTUsv1lLbaYgl6z8MXOE4Ezbpu0y2WUg.PNG/������-�Է����ּ���__���纻-_27_-001.png?type=w2',
#   'https://www.sportschosun.com/article/html/2025/10/22/2025102301001362100180743_w.jpg',
#   'https://img.etoday.co.kr/pto_db/2024/10/20241029063224_2094589_999_567.jpg',
#   'https://blogger.googleusercontent.com/img/b/R29vZ2xl/AVvXsEhIwYdP22bQ2HL4mmF0rsT9O2cpYw8iRkBY4AkpbjujNUkhyphenhyphen-k1BICpkEpj1u1EejbsLIaOld7q40ZSmna-vLCXKj1XNTr8rRHDAB1QhsT-BNRjZkZGPzqPDGc501RlSJyXAx7_HJX2KDCcpZtRWBiUFWbOy6x-MVWIYlHTxsNi6iKnX7ZMjJzvPu6q38jK/s1024/ChatGPT+Image+2025년+10월+11일+오전+11_20_52.png',
#   'https://blog.kakaocdn.net/dn/boRtrn/btsMgUfWOwB/t7Xx4EoLVFU5OrsilmFCmK/img.jpg'],
#  'results': [{'url': 'https://www.chosun.com/sports/baseball/2025/10/31/MQMV676MQJHLNGD7JEIAKWFMEQ/',
#    'title': 'LG, 한화 꺾고 2년 만에 한국시리즈 우승 - 조선일보',
#    'content': '2025 KBO(한국야구위원회)리그 최강자가 가려졌다. 2023시즌 29년만의 통합우승을 이뤄낸 LG가 2시즌 만에 정규시즌과 한국시리즈 우승을 모두 탈환, 한국',
#    'score': 0.99967754,
#    'raw_content': None}],
#  'response_time': 1.27,
#  'request_id': '0cc1e47e-11b3-4a6a-b0dd-d58cbed7917e'}

# %%
##################################################################
# 도구 - 도구 이름, 도구 설명 ==> llm이 도구의 사용 여부를 판단할 때 근거.
# Tavily(built-in) 도구 정보를 확인
##################################################################
print("도구 이름:", tavily_search.name)
print("도구 설명:")
print(tavily_search.description)
# Out:
# 도구 이름: tavily_search
# 도구 설명:
# A search engine optimized for comprehensive, accurate, and trusted results. Useful for when you need to answer questions about current events. It not only retrieves URLs and snippets, but offers advanced search depths, domain management, time range filters, and image search, this tool delivers real-time, accurate, and citation-backed results.Input should be a search query.

# %%
schema = tavily_search.args_schema.model_json_schema()
schema
# 도구 스키마(설계 구조)
## 도구 호출 시 전달 파라미터 정보.
# Out:
# {'additionalProperties': True,
#  'description': 'Input for [TavilySearch]',
#  'properties': {'query': {'description': 'Search query to look up',
#    'title': 'Query',
#    'type': 'string'},
#   'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#    'title': 'Include Domains'},
#   'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#     {'type': 'null'}],
#    'default': [],
#    'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#    'title': 'Exclude Domains'},
#   'search_depth': {'anyOf': [{'enum': ['basic',
#       'advanced',
#       'fast',
#       'ultra-fast'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'basic',
#    'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#    'title': 'Search Depth'},
#   'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#    'default': False,
#    'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#    'title': 'Include Images'},
#   'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': None,
#    'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#    'title': 'Time Range'},
#   'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#      'type': 'string'},
#     {'type': 'null'}],
#    'default': 'general',
#    'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#    'title': 'Topic'},
#   'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#    'title': 'Start Date'},
#   'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#    'default': None,
#    'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#    'title': 'End Date'}},
#  'required': ['query'],
#  'title': 'TavilySearchInput',
#  'type': 'object'}

# %%
schema['properties']
# Out:
# {'query': {'description': 'Search query to look up',
#   'title': 'Query',
#   'type': 'string'},
#  'include_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to restrict search results to.\n\n        Use this parameter when:\n        1. The user explicitly requests information from specific websites (e.g., "Find climate data from nasa.gov")\n        2. The user mentions an organization or company without specifying the domain (e.g., "Find information about iPhones from Apple")\n\n        In both cases, you should determine the appropriate domains (e.g., ["nasa.gov"] or ["apple.com"]) and set this parameter.\n\n        Results will ONLY come from the specified domains - no other sources will be included.\n        Default is None (no domain restriction).\n        ',
#   'title': 'Include Domains'},
#  'exclude_domains': {'anyOf': [{'items': {'type': 'string'}, 'type': 'array'},
#    {'type': 'null'}],
#   'default': [],
#   'description': 'A list of domains to exclude from search results.\n\n        Use this parameter when:\n        1. The user explicitly requests to avoid certain websites (e.g., "Find information about climate change but not from twitter.com")\n        2. The user mentions not wanting results from specific organizations without naming the domain (e.g., "Find phone reviews but nothing from Apple")\n\n        In both cases, you should determine the appropriate domains to exclude (e.g., ["twitter.com"] or ["apple.com"]) and set this parameter.\n\n        Results will filter out all content from the specified domains.\n        Default is None (no domain exclusion).\n        ',
#   'title': 'Exclude Domains'},
#  'search_depth': {'anyOf': [{'enum': ['basic',
#      'advanced',
#      'fast',
#      'ultra-fast'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'basic',
#   'description': 'Controls search thoroughness and result comprehensiveness.\n    \n        Use "basic" for simple queries requiring quick, straightforward answers.\n        \n        Use "advanced" for complex queries, specialized topics, \n        rare information, or when in-depth analysis is needed.\n        \n        Use "fast" for optimized low latency with high relevance.\n        \n        Use "ultra-fast" when latency is prioritized above all else.\n        ',
#   'title': 'Search Depth'},
#  'include_images': {'anyOf': [{'type': 'boolean'}, {'type': 'null'}],
#   'default': False,
#   'description': 'Determines if the search returns relevant images along with text results.\n   \n        Set to True when the user explicitly requests visuals or when images would \n        significantly enhance understanding (e.g., "Show me what black holes look like," \n        "Find pictures of Renaissance art").\n        \n        Leave as False (default) for most informational queries where text is sufficient.\n        ',
#   'title': 'Include Images'},
#  'time_range': {'anyOf': [{'enum': ['day', 'week', 'month', 'year'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': None,
#   'description': 'Limits results to content published within a specific timeframe.\n        \n        ONLY set this when the user explicitly mentions a time period \n        (e.g., "latest AI news," "articles from last week").\n        \n        For less popular or niche topics, use broader time ranges \n        ("month" or "year") to ensure sufficient relevant results.\n   \n        Options: "day" (24h), "week" (7d), "month" (30d), "year" (365d).\n        \n        Default is None.\n        ',
#   'title': 'Time Range'},
#  'topic': {'anyOf': [{'enum': ['general', 'news', 'finance'],
#     'type': 'string'},
#    {'type': 'null'}],
#   'default': 'general',
#   'description': 'Specifies search category for optimized results.\n   \n        Use "general" (default) for most queries, INCLUDING those with terms like \n        "latest," "newest," or "recent" when referring to general information.\n\n        Use "finance" for markets, investments, economic data, or financial news.\n\n        Use "news" ONLY for politics, sports, or major current events covered by \n        mainstream media - NOT simply because a query asks for "new" information.\n        ',
#   'title': 'Topic'},
#  'start_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or after this date.\n        \n        Use this parameter when you need to:\n        - Find recent developments or updates on a topic\n        - Exclude outdated information from search results\n        - Focus on content within a specific timeframe\n        - Combine with end_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-01-15" for January 15, 2024).\n        \n        Examples:\n        - "2024-01-01" - Results from January 1, 2024 onwards\n        - "2023-12-25" - Results from December 25, 2023 onwards\n        \n        When combined with end_date, creates a precise date range filter.\n        \n        Default is None (no start date restriction).\n        ',
#   'title': 'Start Date'},
#  'end_date': {'anyOf': [{'type': 'string'}, {'type': 'null'}],
#   'default': None,
#   'description': 'Filters search results to include only content published on or before this date.\n        \n        Use this parameter when you need to:\n        - Exclude content published after a certain date\n        - Study historical information or past events\n        - Research how topics were covered during specific time periods\n        - Combine with start_date to create a custom date range\n        \n        Format must be YYYY-MM-DD (e.g., "2024-03-31" for March 31, 2024).\n        \n        Examples:\n        - "2024-03-31" - Results up to and including March 31, 2024\n        - "2023-12-31" - Results up to and including December 31, 2023\n        \n        When combined with start_date, creates a precise date range filter.\n        For example: start_date="2024-01-01", end_date="2024-03-31" \n        returns results from Q1 2024 only.\n        \n        Default is None (no end date restriction).\n        ',
#   'title': 'End Date'}}

# %% [markdown]
# ## LLM ToolCalling 흐름
#
# ### 1. Tool 생성 및 LLM Model에 tool binding
# - `LLM-Model.bind_tools(tools=[tool_1, tool_2, ...])`

# %%
from langchain_openai import ChatOpenAI
from langchain_tavily import TavilySearch

tavily_search = TavilySearch(max_results=5)
model = ChatOpenAI(model="gpt-5-mini")  # 뇌 -> 성능 좋은 모델을 사용한다.(판단자)(여기서는 비용문제로 mini 사용)
toolkit = [tavily_search]   # 툴들 모음.(지금은 하나지만 모아줘야한다.)
# model에 tool들을 binding
tool_model = model.bind_tools(tools=toolkit)
# 모델은 그냥 gpt 모델, 실질적 사용은 tool model
print(type(tool_model), type(model))
# Out:
# <class 'langchain_core.runnables.base.RunnableBinding'> <class 'langchain_openai.chat_models.base.ChatOpenAI'>

# %%
# 모델 호출 결과로 사용자에게 응답을 할지, tool을 호출할지 결정
## tool_calls = [] 빈 시퀸스 : 최종응답(content="내용")
## tool_calls =

# %%
# 질문에 따른 응답 차이
## tool이 필요없는 질문.
## content="답변 내용"
## tool_calls=[] "빈 리스트"
result = tool_model.invoke("안녕하세요.")

# %%
print(result.content) # LLM의 응답
print(result.tool_calls) # 빈칸
result
# Out:
# 안녕하세요! 만나서 반갑습니다. 무엇을 도와드릴까요?
# []
# AIMessage(content='안녕하세요! 만나서 반갑습니다. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 1271, 'total_tokens': 1297, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh5iVrTP1aofKMQX5xbmMIQuVrN4', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b726e-4b06-7213-a9d7-c1e041b6e844-0', usage_metadata={'input_tokens': 1271, 'output_tokens': 26, 'total_tokens': 1297, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
## TOOL이 필요한 질문
# 답변 : content="", tool_calls=list[dictionary-호출방식]
result2 = tool_model.invoke("2025년 12월 30일 서울 날씨는 어때?")

# %%
print(result2.content) # 대답이 없다.
result2 # 비어있는 content 확인 가능
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 316, 'prompt_tokens': 1284, 'total_tokens': 1600, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 256, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh5kt27v3AqfSDBu3eT9M8j1G2H6', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b726e-545c-7740-81de-c611ec22bc52-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '2025년 12월 30일 서울 날씨 관측 기상 자료', 'search_depth': 'advanced', 'include_images': False, 'time_range': 'year', 'topic': 'general'}, 'id': 'call_tw0RaiZXUziMIWyixslGwhX0', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1284, 'output_tokens': 316, 'total_tokens': 1600, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 256}})

# %%
vars(result2) # vars(객체) -> 객체의 속성들을 dictionary로 반환 / dict(객체)도 가능
# Out:
# {'content': '',
#  'additional_kwargs': {'refusal': None},
#  'response_metadata': {'token_usage': {'completion_tokens': 316,
#    'prompt_tokens': 1284,
#    'total_tokens': 1600,
#    'completion_tokens_details': {'accepted_prediction_tokens': 0,
#     'audio_tokens': 0,
#     'reasoning_tokens': 256,
#     'rejected_prediction_tokens': 0},
#    'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}},
#   'model_provider': 'openai',
#   'model_name': 'gpt-5-mini-2025-08-07',
#   'system_fingerprint': None,
#   'id': 'chatcmpl-Csh5kt27v3AqfSDBu3eT9M8j1G2H6',
#   'service_tier': 'default',
#   'finish_reason': 'tool_calls',
#   'logprobs': None},
#  'type': 'ai',
#  'name': None,
#  'id': 'lc_run--019b726e-545c-7740-81de-c611ec22bc52-0',
#  'tool_calls': [{'name': 'tavily_search',
#    'args': {'query': '2025년 12월 30일 서울 날씨 관측 기상 자료',
#     'search_depth': 'advanced',
#     'include_images': False,
#     'time_range': 'year',
#     'topic': 'general'},
#    'id': 'call_tw0RaiZXUziMIWyixslGwhX0',
#    'type': 'tool_call'}],
#  'invalid_tool_calls': [],
#  'usage_metadata': {'input_tokens': 1284,
#   'output_tokens': 316,
#   'total_tokens': 1600,
#   'input_token_details': {'audio': 0, 'cache_read': 0},
#   'output_token_details': {'audio': 0, 'reasoning': 256}}}

# %%
print("응답메세지:", result2.content) # ""
print("tool calls:", result2.tool_calls) # list[dict]
# Out:
# 응답메세지:
# tool calls: [{'name': 'tavily_search', 'args': {'query': '2025년 12월 30일 서울 날씨 관측 기상 자료', 'search_depth': 'advanced', 'include_images': False, 'time_range': 'year', 'topic': 'general'}, 'id': 'call_tw0RaiZXUziMIWyixslGwhX0', 'type': 'tool_call'}]

# %% [markdown]
# ### 2. Tool 호출
# - LLM 모델이 tool 요청을 결정한 경우 **어떤 tool을 어떻게 호출할 지** AIMessage의 `tool_calls` 속성에 넣어 반환한다.
# - `tool_calls` 의 호출 정보를 넣어 `tool.invoke()` 호출한다.
#    - `tool.invoke(result.tool_calls[0])`
#    - **반환타입**: `ToolMessage`
#      - Tool의 처리결과를 담는 Message Type 이다.

# %%
# LLM 응답(AIMessage)에 tool_calls가 있을 경우 Tool을 호출

# result2.tool_calls: list[dict]    dict-개별 tool 호출 정보, list는 묶어주는 역할
search_result = tavily_search.invoke(result2.tool_calls[0])
type(search_result)
# Out:
# langchain_core.messages.tool.ToolMessage

# %%
search_result
# Out:
# ToolMessage(content='{"query": "2025년 12월 30일 서울 날씨 관측 기상 자료", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https
우려 등을 고려해 이재명 정부의 집권여당 첫 원내사령탑에 오른 지 200일 만에 자리에서 물러나기로 결정한 것으로 보인다. 김 원내대표 사퇴로 민주당은 차기 원내대표 선거 준비에 들어갈 예정이다. 차기 원내대표는 당헌상 김 전 원내대표의 잔여 임기인 내년 6월 초순까지 약 5개월간 원내 지휘봉을 잡는다. 후보군으로는 박정·백혜련·한병도 의원을 중심으로 조승래 사무총장과 이언주 최고위원 등이 거론되고 있다.](/article/20251230500133) [...] 집회를 열고 동의를 얻는 절차에 착수할 것으로 예상된다.](/article/20251230500118) [\'비위 의혹\' 김병기 원대대표직 사퇴…\\"국민 눈높이 못미쳐 죄송\\"", "score": 0.9954967 ...

# %% [markdown]
# ##### tool_call 이 여러개일 경우
# - 질의에 대해 tool을 여러번 호출 해야 하는 경우 tool_calling 정보를 여러개 반환할 수 있다.
#     - 예) 검색할 키워드가 여러개인 경우.
# - `tool.batch([tool_call1, tool_call2, ..])`

# %%
## tool call이 여러개인 경우.
query = "2025년 KBO, MLB, NPB 리그의 우승팀을 알려줘."
model.invoke(query) # 툴이 없는 경우
# Out:
# AIMessage(content="죄송하지만 제 지식은 2024년 6월까지여서 2025 시즌의 실제 우승팀 결과를 확인할 수 없습니다. 실시간 결과를 바로 알려드리지는 못하지만 다음 중 원하시는 것을 해드릴 수 있습니다.\n\n1) 지금 즉시 2025 우승팀을 '예측'해 드리기(최근 성적·전력 기반으로 근거 함께 제공)  \n2) 사용자가 우승팀을 알려주시면 요약·해설 제공  \n3) 직접 확인하실 수 있는 신뢰할 만한 사이트 안내(예: KBO 공식 사이트 kbo.or.kr, MLB 공식 mlb.com, NPB 공식 npb.jp, 또는 위키피디아의 2025 시즌 페이지들)  \n\n어떤 것을 원하시나요? 예측을 원하시면 바로 시작하겠습니다.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 703, 'prompt_tokens': 26, 'total_tokens': 729, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 512, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh5xL0KAjfQPU8ERcxoMd3ulHeud', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b726e-873a-7073-8f05-9d2518555377-0', usage_metadata={'input_tokens': 26, 'output_tokens': 703, 'total_tokens': 729, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 512}})

# %%
result = tool_model.invoke(query)
result.content
# Out:
# ''

# %%
result.tool_calls # 3번에 걸쳐서 조회
# Out:
# [{'name': 'tavily_search',
#   'args': {'query': '2025 KBO champion Korean Series 2025 우승팀',
#    'search_depth': 'advanced',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_gEfzYZzxUz2t8wLVAmBBQJod',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 MLB World Series champion 2025 World Series winner',
#    'search_depth': 'advanced',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_dZLecfYbeeUYeMlcfaQd5z3L',
#   'type': 'tool_call'},
#  {'name': 'tavily_search',
#   'args': {'query': '2025 NPB champion 2025 Japan Series winner 2025 NPB 우승팀',
#    'search_depth': 'advanced',
#    'include_images': False,
#    'topic': 'general'},
#   'id': 'call_uUOrWSdReUHRLQDazKN5UaDo',
#   'type': 'tool_call'}]

# %%
# for tool_call in result.tool_calls: # LLM이 여러개의 툴을 가지고 있을 경우 반복문을 실행해야.
#     tool_call.name => 호출할 툴 이름 조회
#     tool.invoke(tool_call)
# 위 행위를 한 번에 처리해주는 batch

# Runnable: invoke()/stream() - 개별 요청, batch(): 한 번에 여러개 요청.
search_result_list = tavily_search.batch(result.tool_calls) # [toolcall, toolcall, ...] 한번에 넘겨주기

# %%
search_result_list # list[ToolMessage]
# Out:
# [ToolMessage(content='{"query": "2025 KBO champion Korean Series 2025 우승팀", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://en.wikipedia.org/wiki/2025_KBO_League_season", "title": "2025 KBO League season - Wikipedia", "content": "| Wild Card \\"Wild card (sports)\\") champions | Samsung Lions |\\n| Wild Card runners-up | NC Dinos |\\n| Semi-playoff champions | Samsung Lions |\\n| Semi-playoff runners-up | SSG Landers |\\n| Playoff champions | Hanwha Eagles |\\n| Playoff runners-up | Samsung Lions |\\n| Korean Series |\\n| Date | October 26 - October 31 |\\n| Venue |  Jamsil Baseball Stadium  Daejeon Hanwha Life Ballpark |\\n| Champions | LG Twins (4th title) |\\n| Runners-up | Hanwha Eagles |\\n| Finals MVP | Kim Hyun-soo (LG) | [...] #### 2025 Korean Series\\n\\n[edit]\\n\\nFinals – best of 7 series.\\n\\n##### (1) LG Twins vs (2) Hanwha Eagles\\n\\n[edit LG Twins vs (2) Hanwha Eagles\\")]\\n\\nTwins won the series, 4-1. [...] | Game | Date | Score | Location | Time | Attendance |\\n ---  ---  --- |\\n| 1 | October 18, 2025 | Samsung Lions – 8, Hanwha Eagles – 9 | Daejeon Hanwha Life Ballpark | 3:35 | 16,750 |\\n| 2 | October 19, 2025 | Samsung Lions – 7, Hanwha Eagles – 3 | Daejeon Hanwha Life Ballpark | 3:16 | 16,750 |\\n| 3 | October 21, 2025 | Hanwha Eagles – 5, Samsung Lions – 4 | Daegu Samsung Lions Park | 3:04 | 23,680 |", "score": 0.8706085, "raw_content": null}, {"url": "https://koreajoongangdaily.joins.com/news/2025-10-31/sports/Baseball/LG-Twins-beat-Hanwha-Eagles-to-win-2025-Korea-Series/2434186", "title": "LG Twins beat Hanwha Eagles to win 2025 Korean Series", "content": "The LG Twins won the 2025 Korean Series on Friday, beating the Hanwha Eagles 4-1 in a dominant road performance to win the best-of-seven series in five games.   \\n     \\n The Twins started early at Daejeon Hanwha Life Ballpark in Daejeon, stringing together a run in the first inning before the Eagles tied things up again in the second. The Twins pulled ahead again in the third, adding some insurance in the sixth before compounding the win with a fourth run in the ninth inning. [...] \\">\\n\\nsearch;)\\n\\nyoutube kcampus celeb Newsletter Subscribe Free Sample\\n\\n## korea joongAng daily\\n\\nKorea JoongAng Daily\\n\\n## Home > Sports > Baseball\\n\\ndictionary;)\\n\\n# LG Twins beat Hanwha Eagles to win 2025 Korean Series\\n\\nPublished: 31 Oct. 2025, 21:59  Updated: 31 Oct. 2025, 22:01\\n\\n JIM BULLEY\\n (/cdn-cgi/l/email-protection)\\n\\nThe LG Twins celebrate after winning the 2025 Korean Series at Daejeon Hanwha Life Ballpark in Daejeon on Oct. 31. [YONHAP] [...] BY JIM BULLEY (/cdn-cgi/
ading\\nWorld Baseball Network\\n\\n###### News\\n\\n# NPB: Fukuoka SoftBank Hawks Win 2025 Japan Series\\n\\nThe Hanshin Tigers faithful were left stunned on Thursday night as the Fukuoka SoftBank Hawks clinched the 2025 Japan Series in front of 41,606 fans at Koshien Stadium with a 3-2 extra-inning victory. [...] Had Hanshin come out on top, it would have marked just their third championship in franchise history, following their breakthrough in 2023 that ended the infamous “Curse of the Colonel.” They were also seeking to clinch the Japan Series at home for the first time ever.\\n\\nPhoto: The Fukuoka SoftBank Hawks won the 2025 Japan Series. (Photo Courtesy of the WBSC)\\n\\n###### Table of contents\\n\\n#### Navigation\\n\\n###### Subscribe to our Newsletter!\\n\\n###### Follow Us !\\n\\n###### Related Articles [...] After Hanshin took the opener on the road, SoftBank responded emphatically, winning four straight games to capture their first championship since 2020 and 12th Nippon Professional Baseball title and the 14th in franchise history, including their pre-NPB titles before 1950. First baseman Hotaka Yamakawa was named series MVP after homering in Games 2, 3, and 4.", "score": 0.90633047, "raw_content": null}, {"url": "https://www.wbsc.org/en/news/fukuoka-softbank-hawks-win-2025-japan-series", "title": "Fukuoka Softbank Hawks win 2025 Japan Series - wbsc.org", "content": "30/10/2025 2 Minute Read\\n\\n# Fukuoka Softbank Hawks win 2025 Japan Series\\n\\nIt\'s the first title for the Hawks since 2020 and 12th overall. After tying the best-of-seven series against the Hanshin Tigers at home, the Hawks won three consecutive games by one run at Koshien Stadium. Hotaka Yamakawa (pictured above) earned MVP honours.\\n\\nThe Fukuoka SoftBank Hawks defeated the Hanshin Tigers in five games to claim the 2025 Japan Series title. [...] Tokyo 2020 gold medalist Yuki Yanagida hit a two-run homer off Daichi Ishii to tie the game in the eighth. As the game got to extra innings, the Tigers handed the ball to their ace, Shoki Murakami, game one winner.\\n\\nAfter a scoreless 10th, Isami Nomura led off the 11th with a solo home run to right field that proved  ...

# %% [markdown]
# ### 3. Tool의 처리(응답) 결과를 LLM 요청시 사용
# - ToolMessage를 prompt 에 추가하여 LLM에 요청한다.
# - ToolMessage 는 Tool Calling 정보를 가진 AIMessage 다음에 들어와야 한다.
# - Prompt 순서
#     1. 일반 prompt (system, 대화 history, .., human)
#     2. AIMessage: tool calling 정보를 가진 AIMessage. (tool_model에 질의 받은 tool calling 정보가 있는 응답)
#     3. ToolMessage:  Tool의 처리 결과

# %%
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder

prompt = ChatPromptTemplate(
    [
        ("system", "당신은 AI Assistant입니다. 제공된 정보를 바탕으로 답변을 해주세요."),
        ("human", "{query}"),
        MessagesPlaceholder(variable_name="tool_messages", option=True)
    ]
)

chain = prompt | tool_model
final_result = chain.invoke(
    {
        "query":query,
        "tool_messages":[result, *search_result_list]
    }
)
# "tool_messages":[result:toolcall 정보가 있는 AIMessage, 
#                  *search_result_list: ToolMessage - tool의 처리결과]

# %%
print(final_result.content)
# Out:
# 확인하신 2025년 우승팀은 다음과 같습니다.
#
# - KBO (한국): LG 트윈스 — 2025 한국시리즈 챔피언 (한화 이글스에 4승 1패), 시리즈 MVP: 김현수
# - MLB (미국): 로스앤젤레스 다저스 — 2025 월드 시리즈 챔피언 (토론토 블루제이스에 4승 3패), 월드 시리즈 MVP: 요시노부 야마모토
# - NPB (일본): 후쿠오카 소프트뱅크 호크스 — 2025 일본시리즈 챔피언 (한신 타이거즈에 4승 1패), 시리즈 MVP: 야마카와 호타카
#
# 원하시면 각 경기 요약이나 출처(뉴스·위키피디아 기사) 링크도 공유해 드리겠습니다.

# %%
final_result.tool_calls # -> tool 호출 -> llm 응답
# Out:
# []

# %%
################################
# Agent chain을 구성
################################
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_core.runnables import chain
from langchain_tavily import TavilySearch
from dotenv import load_dotenv
from datetime import date

load_dotenv()
# Out:
# True

# %%
tavily_search = TavilySearch()
model = ChatOpenAI(model="gpt-5-mini")
tool_model = model.bind_tools(tools=[tavily_search]) # model에 TOOL을 binding

system_message = """# Instruction
당신은 다양한 질문에 답을 하는 AI assistant 입니다.
사용자 질문에 대해 최신 정보를 바탕으로 답변해주세요.
오늘 날짜는 {today} 입니다.
필요하다면 tool을 이용해 답변에 필요한 정보를 수집합니다.
당신이 사용할 수 있는 TOOL은 다음과 같습니다.
- tavily_search: 웹 검색 툴"""
today = date.today().strftime("%Y년 %m월 %d일") # %H:시간, %M:분, %S:초
prompt = ChatPromptTemplate(
    [
        ("system", system_message),
        ("human", "{query}"),
        MessagesPlaceholder(variable_name="tool_messages", optional=True)
    ],
    partial_variables={"today":today}
)

tool_model_chain = prompt | tool_model

# %%
tool_model_chain.invoke({"query":"서울 날씨를 알려줘"})
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 174, 'prompt_tokens': 1362, 'total_tokens': 1536, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 128, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh6QBhcfOmiJPNUjt0F5n31AEeKC', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b726e-f9c8-7603-9039-aaa7dd7430e0-0', tool_calls=[{'name': 'tavily_search', 'args': {'query': '서울 날씨', 'search_depth': 'fast', 'time_range': 'day', 'topic': 'general', 'include_images': False}, 'id': 'call_P0Jrx3sTpuixCIVizpFVNoqR', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1362, 'output_tokens': 174, 'total_tokens': 1536, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 128}})

# %%
@chain
def websearch_agent(query:str) -> tuple[str, list]:
    """
    Agent 전체 흐름을 처리하는 Runnable
    사용자 질문(query)를 받아서 tool_model과 tool을 이용해서 최종 응답을 반환한다.
    ReAct 구조로 구성(ReAct Loop)
    """
    ai_messaage = tool_model_chain.invoke({"query":query}) # 반환: 1.실제 응답 또는 2. tool calls 정보
    messages = [] # toolcall메세지, ToolMessage 들을 저장 리스트(prompt tool_message에 넣을 것)
    while ai_messaage.tool_calls: # 빈 리스트가 아니라면
        # tool 호출
        tool_messages = tavily_search.batch(ai_messaage.tool_calls) # [TM, TM, ...]
        messages.extend([ai_messaage, *tool_messages])
        # Tool 호출 결과를 넣어서 tool_model에 다시 요청
        ai_messaage = tool_model_chain.invoke({"query":query, "tool_messages":tool_messages})

    messages.append(ai_messaage)         # 마지막 응답 결과를 추가
    return ai_messaage.content, messages # AIMessage (messages는 어떤 결과인지 확인하기 위함. 굳이 x)

# %%
result = websearch_agent.invoke("안녕하세요.")
result
# Out:
# ('안녕하세요! 반갑습니다. 무엇을 도와드릴까요?',
#  [AIMessage(content='안녕하세요! 반갑습니다. 무엇을 도와드릴까요?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 88, 'prompt_tokens': 1359, 'total_tokens': 1447, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 64, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh6XB15VUo8hAp3jgf3WDm5yGV5W', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019b726f-107d-7713-a993-861591c09eaa-0', usage_metadata={'input_tokens': 1359, 'output_tokens': 88, 'total_tokens': 1447, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 64}})])

# %%
result2 = websearch_agent.invoke("서울 날씨가 어떤지 알려줘.")
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 result2 = websearch_agent.invoke("서울 날씨가 어떤지 알려줘.")
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:4880, in RunnableLambda.invoke(self, input, config, **kwargs)
#    4865 """Invoke this `Runnable` synchronously.
#    4866
#    4867 Args:
#    (...)   4877
#    4878 """
#    4879 if hasattr(self, "func"):
# -> 4880     return self._call_with_config(
#    4881         self._invoke,
#    4882         input,
#    4883         ensure_config(config),
#    4884         **kwargs,
#    4885     )
#    4886 msg = "Cannot invoke a coroutine function synchronously.Use `ainvoke` instead."
#    4887 raise TypeError(msg)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:2058, in Runnable._call_with_config(self, func, input_, config, run_type, serialized, **kwargs)
#    2054     child_config = patch_config(config, callbacks=run_manager.get_child())
#    2055     with set_config_context(child_config) as context:
#    2056         output = cast(
#    2057             "Output",
# -> 2058             context.run(
#    2059                 call_func_with_variable_args,  # type: ignore[arg-type]
#    2060                 func,
#    2061                 input_,
#    2062                 config,
#    2063                 run_manager,
#    2064                 **kwargs,
#    2065             ),
#    2066         )
#    2067 except BaseException as e:
#    2068     run_manager.on_chain_error(e)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:4737, in RunnableLambda._invoke(self, input_, run_manager, config, **kwargs)
#    4735                 output = chunk
#    4736 else:
# -> 4737     output = call_func_with_variable_args(
#    4738         self.func, input_, config, run_manager, **kwargs
#    4739     )
#    4740 # If the output is a Runnable, invoke it
#    4741 if isinstance(output, Runnable):
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\config.py:433, in call_func_with_variable_args(func, input, config, run_manager, **kwargs)
#     431 if run_manager is not None and accepts_run_manager(func):
#     432     kwargs["run_manager"] = run_manager
# --> 433 return func(input, **kwargs)
#
# Cell In[37], line 15, in websearch_agent(query)
#      13     messages.extend([ai_messaage, *tool_messages])
#      14     # Tool 호출 결과를 넣어서 tool_model에 다시 요청
# ---> 15     ai_messaage = tool_model_chain.invoke({"query":query, "tool_messages":tool_messages})
#      17 messages.append(ai_messaage)         # 마지막 응답 결과를 추가
#      18 return ai_messaage.content, messages
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:3151, in RunnableSequence.invoke(self, input, config, **kwargs)
#    3149                 input_ = context.run(step.invoke, input_, config, **kwargs)
#    3150             else:
# -> 3151                 input_ = context.run(step.invoke, input_, config)
#    3152 # finish the root run
#    3153 except BaseException as e:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\runnables\base.py:5557, in RunnableBindingBase.invoke(self, input, config, **kwargs)
#    5550 @override
#    5551 def invoke(
#    5552     self,
#    (...)   5555     **kwargs: Any | None,
#    5556 ) -> Output:
# -> 5557     return self.bound.invoke(
#    5558         input,
#    5559         self._merge_configs(config),
#    5560         **{**self.kwargs, **kwargs},
#    5561     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)    391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)   1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1382, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1380     if raw_response is not None and hasattr(raw_response, "http_response"):
#    1381         e.response = raw_response.http_response  # type: ignore[attr-defined]
# -> 1382     raise e
#    1383 if (
#    1384     self.include_response_headers
#    1385     and raw_response is not None
#    1386     and hasattr(raw_response, "headers")
#    1387 ):
#    1388     generation_info = {"headers": dict(raw_response.headers)}
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\langchain_openai\chat_models\base.py:1377, in BaseChatOpenAI._generate(self, messages, stop, run_manager, **kwargs)
#    1370         return _construct_lc_result_from_responses_api(
#    1371             response,
#    1372             schema=original_schema_obj,
#    1373             metadata=generation_info,
#    1374             output_version=self.output_version,
#    1375         )
#    1376     else:
# -> 1377         raw_response = self.client.with_raw_response.create(**payload)
#    1378         response = raw_response.parse()
#    1379 except Exception as e:
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_legacy_response.py:364, in to_raw_response_wrapper.<locals>.wrapped(*args, **kwargs)
#     360 extra_headers[RAW_RESPONSE_HEADER] = "true"
#     362 kwargs["extra_headers"] = extra_headers
# --> 364 return cast(LegacyAPIResponse[R], func(*args, **kwargs))
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\resources\chat\completions\completions.py:1192, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1145 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1146 def create(
#    1147     self,
#    (...)   1189     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1190 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1191     validate_response_format(response_format)
# -> 1192     return self._post(
#    1193         "/chat/completions",
#    1194         body=maybe_transform(
#    1195             {
#    1196                 "messages": messages,
#    1197                 "model": model,
#    1198                 "audio": audio,
#    1199                 "frequency_penalty": frequency_penalty,
#    1200                 "function_call": function_call,
#    1201                 "functions": functions,
#    1202                 "logit_bias": logit_bias,
#    1203                 "logprobs": logprobs,
#    1204                 "max_completion_tokens": max_completion_tokens,
#    1205                 "max_tokens": max_tokens,
#    1206                 "metadata": metadata,
#    1207                 "modalities": modalities,
#    1208                 "n": n,
#    1209                 "parallel_tool_calls": parallel_tool_calls,
#    1210                 "prediction": prediction,
#    1211                 "presence_penalty": presence_penalty,
#    1212                 "prompt_cache_key": prompt_cache_key,
#    1213                 "prompt_cache_retention": prompt_cache_retention,
#    1214                 "reasoning_effort": reasoning_effort,
#    1215                 "response_format": response_format,
#    1216                 "safety_identifier": safety_identifier,
#    1217                 "seed": seed,
#    1218                 "service_tier": service_tier,
#    1219                 "stop": stop,
#    1220                 "store": store,
#    1221                 "stream": stream,
#    1222                 "stream_options": stream_options,
#    1223                 "temperature": temperature,
#    1224                 "tool_choice": tool_choice,
#    1225                 "tools": tools,
#    1226                 "top_logprobs": top_logprobs,
#    1227                 "top_p": top_p,
#    1228                 "user": user,
#    1229                 "verbosity": verbosity,
#    1230                 "web_search_options": web_search_options,
#    1231             },
#    1232             completion_create_params.CompletionCreateParamsStreaming
#    1233             if stream
#    1234             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1235         ),
#    1236         options=make_request_options(
#    1237             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1238         ),
#    1239         cast_to=ChatCompletion,
#    1240         stream=stream or False,
#    1241         stream_cls=Stream[ChatCompletionChunk],
#    1242     )
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\82107\AppData\Local\Programs\Python\Python313\Lib\site-packages\openai\_base_client.py:1047, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1044             err.response.read()
#    1046         log.debug("Re-raising status error")
# -> 1047         raise self._make_status_error_from_response(err.response) from None
#    1049     break
#    1051 assert response is not None, "could not resolve response (should never happen)"
#
# BadRequestError: Error code: 400 - {'error': {'message': "Invalid parameter: messages with role 'tool' must be a response to a preceeding message with 'tool_calls'.", 'type': 'invalid_request_error', 'param': 'messages.[2].role', 'code': None}}

# %% [markdown]
# # 사용자 정의 Tool 구현
#
# ## @tool 사용
# - 함수로 구현하고 `@tool` 데코레이터를 사용해 tool(StructuredTool)로 정의한다.
#     - `langchain_core.tools` 모듈에 있다.
# - tool name
#     - 함수의 이름이 tool의 이름이 된다.
# - parameters
#     - 함수의 파라미터가 tool의 파라미터가 된다.
#     - **type hint**를 이용해 타입을 지정한다.
# - description
#     - doctring이 description이 된다.
#     - RunnableBinding이 tool을 잘 찾을 수 있도록 하려면 **tool의 기능을 최대한 구체적**으로 작성한다.
# - **@tool이 적용된 함수(StructuredTool)이 tool**이므로 model에 binding 한다.

# %%
from langchain_core.tools import tool

@tool
def plus(num1:int|float,num2:int|float) -> int|float:
    """두개 수를 받아서 덧셈한 결과를 반환하는 툴""" # docstring -> tool 설명(description)
    return num1 + num2

@tool
def minus(num1:int|float,num2:int|float) -> int|float:
    """두개 수를 받아서 뺄셈한 결과를 반환하는 툴""" # docstring -> tool 설명(description)
    return num1 - num2

@tool
def multiply(num1:int|float,num2:int|float) -> int|float:
    """두개 수를 받아서 곱셈한 결과를 반환하는 툴""" # docstring -> tool 설명(description)
    return num1 * num2

# 파라미터에 대한 자세한 설명이 들어가야 하는 경우 -> Pydantic
from pydantic import BaseModel, Field
class DivideParameterSchema(BaseModel):
    num1: int|float = Field(..., description="나눌때 사용할 첫번째 값")
    num2: int|float = Field(..., description="나눌때 사용할 두번째 값")

@tool("divide_tool") # 함수명과 tool의 이름을 따로 줄 수 있다.
def divide(num1:int|float,num2:int|float) -> int|float:
    """두개 수를 받아서 나눗셈한 결과를 반환하는 툴""" # docstring -> tool 설명(description)
    return num1 / num2

# %%
print(type(divide))
print("툴이름:", divide.name)
print("툴설명:", divide.description)
print("args schema(파라미터 설명)")
divide.args_schema.model_json_schema()
# Out:
# <class 'langchain_core.tools.structured.StructuredTool'>
# 툴이름: divide_tool
# 툴설명: 두개 수를 받아서 나눗셈한 결과를 반환하는 툴
# args schema(파라미터 설명)
# {'description': '두개 수를 받아서 나눗셈한 결과를 반환하는 툴',
#  'properties': {'num1': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#    'title': 'Num1'},
#   'num2': {'anyOf': [{'type': 'integer'}, {'type': 'number'}],
#    'title': 'Num2'}},
#  'required': ['num1', 'num2'],
#  'title': 'divide_tool',
#  'type': 'object'}

# %%
calc_model = ChatOpenAI(model="gpt-5-mini").bind_tools(tools=[plus, minus, multiply, divide])
calc_model.invoke("3 + 5 - 20은 얼마야? 계산에 사용할 툴이 있으면 툴을 이용해줘.")
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 220, 'prompt_tokens': 303, 'total_tokens': 523, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 192, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Csh6uJL5B3xNKFNzQXMGDAm1aOUkz', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019b726f-6df2-79c3-a037-208c85ef9932-0', tool_calls=[{'name': 'plus', 'args': {'num1': 3, 'num2': 5}, 'id': 'call_C8nnESmnk3GSivHhiKr0CY9L', 'type': 'tool_call'}], usage_metadata={'input_tokens': 303, 'output_tokens': 220, 'total_tokens': 523, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 192}})

# %% [markdown]
# ## Runnable을 tool로 정의
# - `Runnable객체.as_tool()`
#     - name, description, args_schema 파라미터를 이용해 tool의 이름, 설명, 스키마를 설정한다.

# %%
# uv pip install wikipedia

# %%
from langchain_community.document_loaders import WikipediaLoader
from pydantic import BaseModel, Field
from langchain_core.runnables import chain
import json

@chain
def wikipedia_search(inputs:dict) -> str:
    """사용자 query를 위키백과사전에서 검색하고 검색 결과 중 k개 문서를 반환한다.
    Args:
        inputs(dict): `query-검색할 키워드, max_results(int): 반환할 검색 결과수` 를 받는다.
    Returns:
        str - 검색 결과를 json 으로 반환. 
              형식: {"result":[{검색 문서1}, {검색 문서2}, ...]}. 검색 문서(dict) - content, url, title로 구성
              검색 결과가 없을 경우 : {"result":"결과없음"} 반환.
    """
    query = inputs["query"]
    max_results = inputs.get("max_results", 5)
    loader = WikipediaLoader(query=query, load_max_docs=max_results, lang="ko")
    docs = loader.load()

    result_list = []
    for doc in docs:
        result_list.append({"content":doc.page_content,
                            "title":doc.metadata.get('title'),
                            "url":doc.metadata.get("source")
                            })
    if result_list:
        result = {"result": result_list}
    else:
        result = {"result": "검색 결과가 없습니다."}

    # JSON 문자열로 변환해서 반환.  # json.load() : json문자열 -> 파이썬 자료구조
    #                              json.dump() : 파이썬 자료구조 -> json
    return json.dumps(result, ensure_ascii=False)
    # escape_ascii=False: 한글 문자가 나오도록 처리. True: 한글이 유니코드 escape문자로 나옴(\uxxxx)

# %%
r = wikipedia_search.invoke({"query":"월드컵", "max_results":1})
json.loads(r)
# Out:
# {'result': [{'content': 'FIFA 월드컵(영어: FIFA World Cup)은 축구 국제 기구인 국제 축구 연맹(FIFA)에 가맹한 축구 협회(연맹)의  축구 국가대표팀만 참가하는 국제 축구 대회이다.\n4년마다 열리는 월드컵은 1930년에 첫 대회가 열렸다. 1942년과 1946년 대회는 제2차 세계 대전으로 인하여 열리지 못했다. 대회는 예선 무대와 본선 무대 등 두 부분으로 나뉜다. 예선 무대는 본선에 진출할 32팀을 가려내기 위해 본선 보다 3년 일찍 시작한다. 현재 본선은 개최국 경기장에서 한 달 남짓 32개 팀이 우승을 놓고 경쟁하는 방식으로 진행된다. 월드컵 결승전은 세계에서 가장 많은 사람이 시청하는 단일 스포츠 경기이다. 어림잡아 7억 1,510만 명이 2006년 FIFA 월드컵 결승전을 시청했다고 한다.\n총 20번 대회가 열리는 동안 8팀이 우승을 차지했다. 가장 우승 횟수가 많은 팀은 브라질로 총 다섯 번의 우승컵을 들어올렸다. 그 다음으로 이탈리아와 독일이 네 번, 아르헨티나가 세 번, 그리고 초대 우승팀인 우루과이와 프랑스가 각각 두 차례씩, 잉글랜드와 스페인가 각각 한 차례씩 우승을 차지했다. 네덜란드는 준우승만 3번(1974·1978·2010)했다.대한민국은 4위가 최고 기록이다.(2002)\n가장 최근에 열린 2022년 FIFA 월드컵은 카타르에서 열렸고, 아르헨티나가
막되었다. 그리고 1950년 대회에서는 또한, 제1회 대회의 우승국이었던 우루과이가 이전 두 대회의 참가 거부 끝에 복귀했다. 우루과이는 이 대회에서 다시 한 번 우승했고 이 대회는 마라카낭의 비극이라고 하는 역사상 유명한 경기로 후에 남게 되었다. 우루과이에 패배한 브라질은 그 굴욕을 참지 못해 유니폼의 색깔이 변경되었다.\n1934년부터 1978년 대회까지는 1938년 대회에서 오스트리아가 나치 독일에 예선 통과 후에 흡수됨에 따라 15개 팀의 참가로 치러진 경우와, 1950년 대회에서 인도, 스코틀랜드, 터키가 기권해서 13개 팀의 참가로 치러진 경 ...
#    'title': 'FIFA 월드컵',
#    'url': 'https://ko.wikipedia.org/wiki/FIFA_%EC%9B%94%EB%93%9C%EC%BB%B5'}]}

# %%
# Runnable을 tool로 변환 -> as_tool(툴 설정)
## args_schema 설정
class WikiSearchParameterSchema(BaseModel):
    query: str = Field(..., description="Wikipedia 에서 검색할 keyword")
    max_results: int = Field(default=5, description="검색할 결과 문서의 최대 개수. 생략하면 5개를 검색.")

search_wiki = wikipedia_search.as_tool(
    args_schema=WikiSearchParameterSchema,
    name="search_wiki",
    description="""이 도구는 위키피디아에서 정보를 검색할 때 사용한다.
사용자의 질문과 관련된 내용을 위키피디아에서 검색해서 지정한 개수의 문서만큼 반환한다.
일반적인 지식이나 백과사전 식 정보가 필요할 때 사용한다.
"""
)

# %%
print(search_wiki.name)
print(search_wiki.description)
search_wiki.args_schema.model_json_schema()
# Out:
# search_wiki
# 이 도구는 위키피디아에서 정보를 검색할 때 사용한다.
# 사용자의 질문과 관련된 내용을 위키피디아에서 검색해서 지정한 개수의 문서만큼 반환한다.
# 일반적인 지식이나 백과사전 식 정보가 필요할 때 사용한다.
# {'properties': {'query': {'description': 'Wikipedia 에서 검색할 keyword',
#    'title': 'Query',
#    'type': 'string'},
#   'max_results': {'default': 5,
#    'description': '검색할 결과 문서의 최대 개수. 생략하면 5개를 검색.',
#    'title': 'Max Results',
#    'type': 'integer'}},
#  'required': ['query'],
#  'title': 'WikiSearchParameterSchema',
#  'type': 'object'}

# %%
tool_model = ChatOpenAI(model="gpt-5-mini").bind_tools(tools=[search_wiki])

res = tool_model.invoke("월드컵에 대한 내용을 위키백과사전에서 조회해서 정리해줘")

# %%
print(res.content)
res.tool_calls
# Out:
# [{'name': 'search_wiki',
#   'args': {'query': '월드컵', 'max_results': 5},
#   'id': 'call_nnuqgVfFMGrAUG9Zhk5s2wZx',
#   'type': 'tool_call'}]

# %% [markdown]
# ## Vector Store(Vector 저장소) tool
#
# ### text loading -> Document 생성
# - 레스토랑 메뉴를 vector store에 저장한다.
# 1. 메뉴 text 를 로딩한다.
# 2. 각 메뉴의 내용(음식이름, 메뉴설명, 파일명)을 넣어 Document를 생성한다.

# %%
# 문서 Load
import os
# 메뉴읽어 오기
menu_file_path = "data/restaurant_menu.txt"
with open(menu_file_path, "r", encoding="utf-8") as f:
    menu = f.read()

# %%
# Split - 메뉴별로 분리하기 위해 직접 처리
from langchain_core.documents import Document
import re
from pprint import pprint

def create_documents(menu_all: str, file_name) -> list[Document]:
    """메뉴별로 분리 한뒤 Document로 변환. 변환된 Document들을 리스트로 반환
    metadata: 메뉴이름, 주요 재료, 가격, source(파일이름)
    """
    menu_list = menu_all.split("\n\n")
    menu_documents = [] # 개별 메뉴로 Document를 생성. 그것들을 저장할 list
    for menu_item in menu_list:

        # 메뉴 이름 추출
        menu_name_pattern = r"(^\d+.\s)([가-힣a-zA-Z\d ]+)"
        menu_name_result = re.search(menu_name_pattern, menu_item)
        menu_name = menu_name_result.group(2).strip()  # 메뉴 이름 추출 # 1은 번호

        # 주요재료 추출 - text로 indexing.
        menu_ingredient_pattern = r"(?<=주요 재료: ).+"
        ingredients = re.search(menu_ingredient_pattern, menu_item).group().strip()
    
        # 가격추출
        price_pattern = r"(?<=가격: )[\d,]+(?=원)"
        price_result = re.search(price_pattern, menu_item)
        price = int(price_result.group().replace(",", ""))

        
        # 메뉴 이름을 제외한 나머지는 메뉴 설명으로 간주
        menu_doc = Document(
            page_content=menu_item,     # 메뉴 설명을 page_content에 넣는다. metadata는 나중에 따로 따로 payload filtering 할 수있기 때문에 
            metadata={
                "menu_name": menu_name, # 메뉴 이름
                "price": price,         # 가격
                "ingredients": ingredients, # 재료 리스트
                "source": file_name     # 메뉴가 저장된 파일 이름
            }
        )
        menu_documents.append(menu_doc)
    return menu_documents


menu_documents = create_documents(menu, menu_file_path)
print(len(menu_documents))
# Out:
# 15

# %%
# VectorDB 저장 및 VectorStore 생성
from langchain_qdrant import QdrantVectorStore
from langchain_openai import OpenAIEmbeddings
from qdrant_client import QdrantClient
from qdrant_client.http.models import Distance, VectorParams
from dotenv import load_dotenv

load_dotenv()

COLLECTION_NAME = "restaurant_menu"
VECTOR_SIZE = 1536  # OpenAIEmbeddings의 벡터 크기

embeddings = OpenAIEmbeddings(model="text-embedding-3-small")

client = QdrantClient(host="localhost", port=6333)
if client.collection_exists(COLLECTION_NAME):
    client.delete_collection(COLLECTION_NAME)

# Collection 생성
client.create_collection(
    collection_name=COLLECTION_NAME,
    # 벡터 저장소에 대한 설정. - vector_config는 default이므로 이름을 안줘도 됨(default 로 잡힘) 이름을 줄 거면 {"이름":VectorParams()} 설정
    vectors_config=VectorParams(
        size=VECTOR_SIZE, 
        distance=Distance.COSINE
    )
)

vectorstore = QdrantVectorStore(
    client=client, # QdrantClient
    embedding=embeddings, # Embedding Model
    collection_name=COLLECTION_NAME # 연결할 Collection 지정.
)
ids = vectorstore.add_documents(menu_documents)
print(f"저장된 문서 개수: {len(ids)}")
##################################################
# Retriever 생성
##################################################
menu_retriever = vectorstore.as_retriever(
    search_kwargs={"k": 3}  # 검색할 결과 개수
)

from langchain_core.runnables import ConfigurableField
retriever = menu_retriever.configurable_fields(
    search_type=ConfigurableField(
        id="search_type"
    ),
    search_kwargs=ConfigurableField(
        id="search_kwargs"
    ),
)
# Out:
# 저장된 문서 개수: 15

# %%
query = "프랑스 음식을 추천해줘."
query = "이태리 음식을 추천해줘."
# query = "쇠고기를 재료로 하는 음식은 뭐가 있어?"
result = retriever.invoke(query)

for doc in result:
    print(doc.metadata)
# Out:
# {'menu_name': '트러플 피자', 'price': 26000, 'ingredients': '트러플 오일, 모짜렐라 치즈, 얇은 피자 도우, 루꼴라', 'source': 'data/restaurant_menu.txt', '_id': '4fab8015-8395-42ec-8b84-8c210cd4c6b9', '_collection_name': 'restaurant_menu'}
# {'menu_name': '레몬 타르트', 'price': 9000, 'ingredients': '레몬 커드, 타르트 크러스트, 슈거 파우더', 'source': 'data/restaurant_menu.txt', '_id': 'd191eadf-d8a9-4785-a587-85a183017784', '_collection_name': 'restaurant_menu'}
# {'menu_name': '부르기뇽 스튜', 'price': 28000, 'ingredients': '쇠고기, 적포도주, 양파, 당근, 베이컨', 'source': 'data/restaurant_menu.txt', '_id': '3290d276-faf2-4348-88b4-1060097ec318', '_collection_name': 'restaurant_menu'}

# %%
# Retriever를 tool로 사용
# query를 입력 받아서 retriever로 검색해서 그 결과를 반환하는 tool을 직접 구현.

# %% [markdown]
# # create_agent() 를 이용한 Agent 구현
#
# - create_agent()
#   - Agent 생성 및 실행을 표준화, 단순화 하기 위헤 Langchain 1.0에서 도입된 함수
#   - 0.x 버전까지는 Agent 생성 함수는
#     1. model과 tool들을 넣어 Agent를 생성하고
#     2. 그것을 실행하는 Executor를 생성하는 방식으로
#   - 여러 단계를 거쳐야 했다.
#   - create_agent()는 이러한 단계를 1단계로 축약한 API이다.
#
# - create_agent 설계 철학
#     1. Agent를 구성하는 모든 실행단위는 Runnable 이다.
#     2. Agent도 Runnable 이다.
#     3. Agent는 하나의 표준 팩토리 함수(생성함수)로 통합한다.
#
# ## 주요 파라미터
# - https://reference.langchain.com/python/langchain/agents/
# - `model`: LLM 모델. Agent의 두뇌 역할을 하며 추론(Reasoning), 도구 선택, 최종 응답을 담당한다.
# - `tools`: Agent가 사용할 외부 도구모음.
# - `system_prompt`

# %% [markdown]
# # LangChain에서 MCP 연동
#
# ## MCP란
#
# - **MCP**(**Model Context Protocol**)는 Anthropic이 주도하여 2024년 말에 발표한 개방형 표준으로, LLM 애플리케이션이 외부 데이터 소스나 도구에 접근하는 방식을 표준화 하는 프로토콜이다.
#   - Agent가 이용할 수 있는 tool을 구현하는 방법은 framework 마다 다르기 때문에 서로 호환 되지 않는 문제가 있다.
#   - MCP는 이런 문제를 해결하기 위해 만든 표준 프로토콜이다.
#
# ## MCP 아키텍처 구성 요소
# - **MCP 호스트**
#   -  AI 애플리케이션(예: LLM 채팅 애플리케이션)으로 MCP 클라이언트를 통해 여러 서버에 연결한다.
#
# - **MCP 클라이언트**
#   -  각 MCP 서버와의 연결을 유지하는 구성요소로, 서버로부터 도구/리소스/프롬프트를 가져와 LLM 모델에게 전달한다.
#
# - **MCP 서버**
#   -  외부 데이터 소스나 Tool들을 제공하는 프로그램이다. 서버는 도구, 리소스, 프롬프트를 노출하고 클라이언트와 JSON‑RPC 2.0 메시지로 통신한다.
#   -  MCP는 서버 클라이언트 간의 **로컬 프로세스 간 통신을 위한 STDIO**와 **원격 서버 접속을 위한 Streamable HTTP** 두 가지 전송 방식을 지원한다
#   -  **MCP 서버가 제공하는 것**
#      -  **도구**(**Tools**): LLM이 호출할 수 있는 함수형 작업이다. 예를 들어 “queryDatabase”, “sendEmail” 등이 있으며 각 도구는 이름, 설명, 입력 스키마를 포함한다.
#      -  **리소스**(**Resources**): 읽기 전용 데이터 소스로, 검색 색인·파일시스템·데이터베이스 등에서 컨텍스트를 제공한다.
#      -  **프롬프트**(**Prompts**): LLM 프롬프트 템플릿이나 예시를 서버에서 제공해 AI 모델의 질의를 돕는다.
#
#
# ## 사용 가능한 MCP 툴 찾기
#
# - MCP 생태계에는 수천 개의 툴 서버가 이미 공개되어 있으며, 원하는 기능의 툴을 검색하여 사용할 수 있다.
# - MCP 검색 및 서비스 사이트
#   - [PulseMCP](pulsemcp.com)
#   - [MCP 마켓](https://mcpmarket.com/ko)
#   - [MCP Servers](https://mcp.so/)
#   - [smithery](https://smithery.ai/servers)

# %% [markdown]
# ## LangChain에서 MCP 툴 연동하기
#
# - LangChain에서 MCP 서버와 연동하기 위해서는 Adapter lib 설치가 필요하다.
#   - `pip install langchain-mcp-adapters`
#
# ###  MultiServerMCPClient
# - **MCP 클라이언트 객체**로, LangChain에서 **하나 이상의 MCP 서버를 연결하고 Tool 목록을 가져오기 위해 사용**한다.
#     - 여러 개의 MCP 서버를 **동시에 등록하고 연결**할 수 있다.
#     - 서버 설정들을 **하나의 딕셔너리**(**Dictionary**)로 묶어 전달하며, **각 개별 서버 역시 Dictionary로 설정**한다.
#     - MCP 클라이언트에 등록된 모든 서버는 이후 `get_tools()` 호출을 통해 서버가 제공하는 tool들을 **LangChain의 Tool 객체로 자동 변환해 Agent가 호출**(**사용**)할 수있게 한다.
#
# #### 개별 서버 설정 Key 정의
# - **`dict[str: 서버 별칭, dict: 서버 설정]`**
#
# | 설정 Key        | 의미                                                                  | 사용 예                            |
# | --------------- | --------------------------------------------------------------------- | ---------------------------------- |
# | **`transport`** | 서버와 통신하는 방식                                                  | `"stdio"` 또는 `"streamable-http"` |
# | **`command`**   | MCP 서버를 실행할 프로그램(프로세스)                                  | `"python"` 또는 `"npx"`            |
# | **`args`**      | command에 전달할 세부 실행 인자를 **리스트(List)**에 문자열로 순서대로 배치 | `["-m", "mcp_server_time"]`  |
#
# - **transport 값에 따른 동작 구분**
#     - `"stdio"`: 로컬에서 실행되는 서버 연결
#     - `"streamable-http"`: 원격 MCP 서버(서비스형) 연결
#
#     ```json
#         {
#             "time": {
#                 "transport": "stdio",
#                 "command": "python",
#                 "args": ["-m", "mcp_server_time"]
#             }
#
#             "github": {
#                 "transport": "streamable-http",
#                 "url": "https://server.smithery.ai/github",
#             }
#         }
#     ```
#
# #### command + args 와 실행 명령어 관계
#
# | 실제 실행 명령                    | 설정으로 표현되는 방식                                             |
# | --------------------------- | -------------------------------------------------------- |
# | `python -m mcp_server_time` | `"command": "python", "args": ["-m", "mcp_server_time"]` |
# | `npx -y @org/server`        | `"command": "npx", "args": ["-y", "@org/server"]`        |
#
# * **command는 실행 프로그램**, args는 **명령 뒤에 붙는 옵션을 순서 그대로 리스트에 나열**한다.
