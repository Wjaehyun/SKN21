# %% [markdown]
# # 성능개선 기법 실습

# %% [markdown]
# # 모듈 정의

# %% [markdown]
# ## train.py
#
# -   모델 학습과 검증 함수 정의

# %%
import os

os.makedirs("module", exist_ok=True)

# %%
# %%writefile module/train.py

import torch
import time

def test_multi_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    다중 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() 
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            # 정확도 계산
            pred_label = torch.argmax(pred, axis=-1)
            test_accuracy += torch.sum(pred_label == y).item()
            
        test_loss /= num_steps
        test_accuracy /= size
    return test_loss, test_accuracy

def test_binary_classification(dataloader, model, loss_fn, device="cpu") -> tuple:
    """
    이진 분류 검증/평가 함수
    
    Args:
        dataloader: DataLoader - 검증할 대상 데이터로더
        model: 검증할 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
    Returns:
        tuple: (loss, accuracy)
    """
    model.to(device)
    model.eval() # 모델을 평가모드로 변환
    size = len(dataloader.dataset)
    num_steps = len(dataloader)
    
    test_loss, test_accuracy = 0., 0.
    
    with torch.no_grad():
        for X, y in dataloader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            test_loss += loss_fn(pred, y).item()
            ## 정확도 계산
            pred_label = (pred >= 0.5).type(torch.int32)
            test_accuracy += (pred_label == y).sum().item() 
            
        test_loss /= num_steps
        test_accuracy /= size   #전체 개수로 나눈다.
    return test_loss, test_accuracy    

def train(dataloader, model, loss_fn, optimizer, device="cpu", mode:"binary or multi"='binary'):
    """
    모델을 1 epoch 학습시키는 함수

    Args:
        dataloader: DataLoader - 학습데이터셋을 제공하는 DataLoader
        model - 학습대상 모델
        loss_fn: 모델 추정값과 정답의 차이를 계산할 loss 함수.
        optimizer - 최적화 함수
        device: str - 연산을 처리할 장치. default-"cpu", gpu-"cuda"
        mode: str - 분류 종류. binary 또는 multi
    
    Returns:
        tuple: 학습후 계산한 Train set에 대한  train_loss, train_accuracy
    """
    model.train()

    for X, y in dataloader:
        X, y = X.to(device), y.to(device)
        pred = model(X)

        loss = loss_fn(pred, y)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
    if mode == 'binary':
        train_loss, train_accuracy = test_binary_classification(dataloader, model, loss_fn, device)
    else:
        train_loss, train_accuracy = test_multi_classification(dataloader, model, loss_fn, device)
    return train_loss, train_accuracy



def fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model=True, 
        save_model_path=None, early_stopping=True, patience=10, device='cpu',  mode:"binary or multi"='binary',
        lr_scheduler=None):
    """
    모델을 학습시키는 함수

    Args:
        train_loader (Dataloader): Train dataloader
        test_loader (Dataloader): validation dataloader
        model (Module): 학습시킬 모델
        loss_fn (_Loss): Loss function
        optimizer (Optimizer): Optimizer
        epochs (int): epoch수
        save_best_model (bool, optional): 학습도중 성능개선시 모델 저장 여부. Defaults to True.
        save_model_path (str, optional): save_best_model=True일 때 모델저장할 파일 경로. Defaults to None.
        early_stopping (bool, optional): 조기 종료 여부. Defaults to True.
        patience (int, optional): 조기종료 True일 때 종료전에 성능이 개선될지 몇 epoch까지 기다릴지 epoch수. Defaults to 10.
        device (str, optional): device. Defaults to 'cpu'.
        mode(str, optinal): 분류 종류. "binary(default) or multi
        lr_scheduler: Learning Rate Scheduler 객체. default: None, Epoch 단위로 LR 를 변경.
    
    Returns:
        tuple: 에폭 별 성능 리스트. (train_loss_list, train_accuracy_list, validation_loss_list, validataion_accuracy_list)
    """

    train_loss_list = []
    train_accuracy_list = []
    val_loss_list = []
    val_accuracy_list = []
    
        
    if save_best_model:
        best_score_save = torch.inf

    ############################
    # early stopping
    #############################
    if early_stopping:
        trigger_count = 0
        best_score_es = torch.inf
    
    # 모델 device로 옮기기
    model = model.to(device)
    s = time.time()
    for epoch in range(epochs):
        train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
        ############ 1 epoch 학습 종료 -> LR 를 변경 ###########
        if lr_scheduler is not None:
            current_lr = lr_scheduler.get_last_lr()[0]  # log용
            lr_scheduler.step()
            new_lr = lr_scheduler.get_last_lr()[0] # log용
            if current_lr != new_lr: # LR가 변경되었으면
                print(f">>>>>>Learning Rate가 {current_lr}에서 {new_lr}로 변경됨<<<<<<")

        
        if mode == "binary":
            val_loss, val_accuracy = test_binary_classification(val_loader, model, loss_fn, device=device)
        else:
            val_loss, val_accuracy = test_multi_classification(val_loader, model, loss_fn, device=device)

        train_loss_list.append(train_loss)
        train_accuracy_list.append(train_accuracy)
        val_loss_list.append(val_loss)
        val_accuracy_list.append(val_accuracy)
        
        print(f"Epoch[{epoch+1}/{epochs}] - Train loss: {train_loss:.5f} Train Accucracy: {train_accuracy:.5f} || Validation Loss: {val_loss:.5f} Validation Accuracy: {val_accuracy:.5f}")
        print('='*100)
        
        # 모델 저장
        if save_best_model:
            if val_loss < best_score_save:
                torch.save(model, save_model_path)
                print(f"저장: {epoch+1} - 이전 : {best_score_save}, 현재: {val_loss}")
                best_score_save = val_loss
        
        # early stopping 처리            
        if early_stopping:
            if val_loss < best_score_es: 
                best_score_es = val_loss  
                trigger_count = 0
                                
            else:
                trigger_count += 1                
                if patience == trigger_count:
                    print(f"Early stopping: Epoch - {epoch}")
                    break
            
    e = time.time()
    print(e-s, "초")
    return train_loss_list, train_accuracy_list, val_loss_list, val_accuracy_list
# Out:
# Writing module/train.py

# %% [markdown]
# ## data.py
#
# -   dataset 생성 함수 제공 모듈

# %%
# %%writefile module/data.py

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

def load_mnist_dataset(root_path, batch_size, is_train=True):
    """
    mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader 
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.MNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader

def load_fashion_mnist_dataset(root_path, batch_size, is_train=True):
    """
    fashion mnist dataset dataloader 제공 함수
    Args:
        root_path: str|Path - 데이터파일 저장 디렉토리
        batch_size: int
        is_train: bool = True - True: Train dataset, False - Test dataset
    
    Returns:
        DataLoader
    """
    transform = transforms.Compose([
        transforms.ToTensor()
    ])
    dataset = datasets.FashionMNIST(root=root_path, train=is_train, download=True, transform=transform)
    dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=is_train)  # shuffle: train이면 True, test면 False 할 것이므로 is_train을 넣음.
    
    return dataloader
# Out:
# Writing module/data.py

# %% [markdown]
# ## utils.py

# %%
# %%writefile module/utils.py
# 학습 결과를 시각화하는 함수.
import matplotlib.pyplot as plt

def plot_fit_result(train_loss_list, train_accuracy_list, valid_loss_list, valid_accuracy_list):
    """epoch별 학습 결과를 시각화하는 함수
    epoch별 loss와 accuracy를 시각화한다.

    Args:
        train_loss_list (list): Epoch별 train loss
        train_accuracy_list (list): Epoch별 train accuracy
        valid_loss_list (list): Epoch별 validation loss
        valid_accuracy_list (list): Epoch별 validation accuracy
    """
    epoch = len(train_loss_list)
    plt.figure(figsize=(12, 5))
    
    plt.subplot(1, 2, 1)
    plt.plot(range(epoch), train_loss_list, label="train loss")
    plt.plot(range(epoch), valid_loss_list, label="validation loss")
    plt.title("Loss")
    plt.xlabel("epoch")
    plt.ylabel("loss")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(range(epoch), train_accuracy_list, label="train accuracy")
    plt.plot(range(epoch), valid_accuracy_list, label="validation accuracy")
    plt.title("Accuracy")
    plt.xlabel("epoch")
    plt.ylabel("accuracy")
    plt.grid(True, linestyle=':')
    plt.legend()

    plt.tight_layout()
    plt.show()
# Out:
# Writing module/utils.py

# %% [markdown]
# ## Import

# %%
import torch
import torch.nn as nn
from torchinfo import summary

from module.train import fit
from module.data import load_mnist_dataset, load_fashion_mnist_dataset
from module.utils import plot_fit_result

# %% [markdown]
# ## 하이퍼파라미터, 변수 정의

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
root_data_path = "datasets"

epochs = 100
batch_size = 256
lr = 0.001

# %% [markdown]
# # Data 준비
#
# ## mnist 데이터 로딩

# %%
train_loader = load_mnist_dataset(root_data_path, batch_size)
test_loader = load_mnist_dataset(root_data_path, batch_size, False)

## Fashion Mnist
# train_loader = load_fashion_mnist_dataset(root_data_path, batch_size)
# test_loader = load_fashion_mnist_dataset(root_data_path, batch_size, False)

# %%
classes = train_loader.dataset.classes
class_to_idx = train_loader.dataset.class_to_idx

# %%
class_to_idx
# Out:
# {'0 - zero': 0,
#  '1 - one': 1,
#  '2 - two': 2,
#  '3 - three': 3,
#  '4 - four': 4,
#  '5 - five': 5,
#  '6 - six': 6,
#  '7 - seven': 7,
#  '8 - eight': 8,
#  '9 - nine': 9}

# %% [markdown]
# # 모델의 크기 변경에 따른 성능변화
# ## 작은 모델

# %%
class SmallModel(nn.Module):
    
    def __init__(self):
        super().__init__()
        self.lr1 = nn.Linear(784, 16)
        self.lr2 = nn.Linear(16, 10)
        self.relu = nn.ReLU()

    def forward(self, X):
        out = nn.Flatten()(X) # (N, 1, 28, 28) -> (N, 1*28*28)
        out = self.relu(self.lr1(out))
        out = self.lr2(out)
        return out

# %%
summary(SmallModel(), (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# SmallModel                               [100, 10]                 --
# ├─Linear: 1-1                            [100, 16]                 12,560
# ├─ReLU: 1-2                              [100, 16]                 --
# ├─Linear: 1-3                            [100, 10]                 170
# ==========================================================================================
# Total params: 12,730
# Trainable params: 12,730
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 1.27
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.05
# Estimated Total Size (MB): 0.39
# ==========================================================================================

# %%
small_model = SmallModel()
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(small_model.parameters(), lr=lr)

# %%
result = fit(train_loader, test_loader, small_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.41976 Train Accucracy: 0.88848 || Validation Loss: 0.39978 Validation Accuracy: 0.89120
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.32605 Train Accucracy: 0.91027 || Validation Loss: 0.31441 Validation Accuracy: 0.90940
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.29429 Train Accucracy: 0.91742 || Validation Loss: 0.28434 Validation Accuracy: 0.91640
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.27689 Train Accucracy: 0.92153 || Validation Loss: 0.26970 Validation Accuracy: 0.92220
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.26554 Train Accucracy: 0.92540 || Validation Loss: 0.26293 Validation Accuracy: 0.92330
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.25297 Train Accucracy: 0.92892 || Validation Loss: 0.25633 Validation Accuracy: 0.92530
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.23933 Train Accucracy: 0.93208 || Validation Loss: 0.24253 Validation Accuracy: 0.92920
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.22981 Train Accucracy: 0.93548 || Validation Loss: 0.23535 Validation Accuracy: 0.93100
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.21958 Train Accucracy: 0.93885 || Validation Loss: 0.22584 Validation Accuracy: 0.93440
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.21014 Train Accucracy: 0.94098 || Validation Loss: 0.21680 Validation Accuracy: 0.93640
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.20288 Train Accucracy: 0.94257 || Validation Loss: 0.21258 Validation Accuracy: 0.93720
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.19658 Train Accucracy: 0.94395 || Validation Loss: 0.20691 Validation Accuracy: 0.93910
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.18941 Train Accucracy: 0.94610 || Validation Loss: 0.20134 Validation Accuracy: 0.94090
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.18284 Train Accucracy: 0.94805 || Validation Loss: 0.19420 Validation Accuracy: 0.94290
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.18095 Train Accucracy: 0.94915 || Validation Loss: 0.19554 Validation Accuracy: 0.94210
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.17281 Train Accucracy: 0.95103 || Validation Loss: 0.18710 Validation Accuracy: 0.94380
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.16771 Train Accucracy: 0.95287 || Validation Loss: 0.18245 Validation Accuracy: 0.94510
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.16407 Train Accucracy: 0.95395 || Validation Loss: 0.17984 Validation Accuracy: 0.94570
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.16141 Train Accucracy: 0.95453 || Validation Loss: 0.17847 Validation Accuracy: 0.94840
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.15699 Train Accucracy: 0.95550 || Validation Loss: 0.17463 Validation Accuracy: 0.94770
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.15399 Train Accucracy: 0.95637 || Validation Loss: 0.17365 Validation Accuracy: 0.94840
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.15084 Train Accucracy: 0.95738 || Validation Loss: 0.17318 Validation Accuracy: 0.94780
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.14824 Train Accucracy: 0.95760 || Validation Loss: 0.17107 Validation Accuracy: 0.94790
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.14411 Train Accucracy: 0.95942 || Validation Loss: 0.16880 Validation Accuracy: 0.94940
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.14104 Train Accucracy: 0.95990 || Validation Loss: 0.16693 Validation Accuracy: 0.94990
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.13901 Train Accucracy: 0.96025 || Validation Loss: 0.16524 Validation Accuracy: 0.95100
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.13691 Train Accucracy: 0.96092 || Validation Loss: 0.16390 Validation Accuracy: 0.95200
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.13653 Train Accucracy: 0.96107 || Validation Loss: 0.16501 Validation Accuracy: 0.94990
# ====================================================================================================
# Epoch[29/100] - Train loss: 0.13294 Train Accucracy: 0.96247 || Validation Loss: 0.16318 Validation Accuracy: 0.95160
# ====================================================================================================
# Epoch[30/100] - Train loss: 0.13130 Train Accucracy: 0.96262 || Validation Loss: 0.16304 Validation Accuracy: 0.95090
# ====================================================================================================
# Epoch[31/100] - Train loss: 0.13064 Train Accucracy: 0.96328 || Validation Loss: 0.16257 Validation Accuracy: 0.95120
# ====================================================================================================
# Epoch[32/100] - Train loss: 0.12717 Train Accucracy: 0.96367 || Validation Loss: 0.16065 Validation Accuracy: 0.95140
# ====================================================================================================
# Epoch[33/100] - Train loss: 0.12690 Train Accucracy: 0.96368 || Validation Loss: 0.16185 Validation Accuracy: 0.95050
# ====================================================================================================
# Epoch[34/100] - Train loss: 0.12507 Train Accucracy: 0.96378 || Validation Loss: 0.16041 Validation Accuracy: 0.95090
# ====================================================================================================
# Epoch[35/100] - Train loss: 0.12336 Train Accucracy: 0.96485 || Validation Loss: 0.16079 Validation Accuracy: 0.95150
# ====================================================================================================
# Epoch[36/100] - Train loss: 0.11968 Train Accucracy: 0.96573 || Validation Loss: 0.15996 Validation Accuracy: 0.95100
# ====================================================================================================
# Epoch[37/100] - Train loss: 0.12109 Train Accucracy: 0.96510 || Validation Loss: 0.16094 Validation Accuracy: 0.95130
# ====================================================================================================
# Epoch[38/100] - Train loss: 0.11924 Train Accucracy: 0.96562 || Validation Loss: 0.16027 Validation Accuracy: 0.95110
# ====================================================================================================
# Epoch[39/100] - Train loss: 0.11958 Train Accucracy: 0.96517 || Validation Loss: 0.16237 Validation Accuracy: 0.95120
# ====================================================================================================
# Epoch[40/100] - Train loss: 0.11643 Train Accucracy: 0.96602 || Validation Loss: 0.16051 Validation Accuracy: 0.94980
# ====================================================================================================
# Epoch[41/100] - Train loss: 0.11470 Train Accucracy: 0.96727 || Validation Loss: 0.16113 Validation Accuracy: 0.95300
# ====================================================================================================
# Epoch[42/100] - Train loss: 0.11497 Train Accucracy: 0.96655 || Validation Loss: 0.16069 Validation Accuracy: 0.95150
# ====================================================================================================
# Epoch[43/100] - Train loss: 0.11183 Train Accucracy: 0.96813 || Validation Loss: 0.15880 Validation Accuracy: 0.95260
# ====================================================================================================
# Epoch[44/100] - Train loss: 0.11178 Train Accucracy: 0.96740 || Validation Loss: 0.15786 Validation Accuracy: 0.95120
# ====================================================================================================
# Epoch[45/100] - Train loss: 0.10997 Train Accucracy: 0.96878 || Validation Loss: 0.16006 Validation Accuracy: 0.95230
# ====================================================================================================
# Epoch[46/100] - Train loss: 0.10865 Train Accucracy: 0.96883 || Validation Loss: 0.15791 Validation Accuracy: 0.95220
# ====================================================================================================
# Epoch[47/100] - Train loss: 0.10865 Train Accucracy: 0.96825 || Validation Loss: 0.16198 Validation Accuracy: 0.95190
# ====================================================================================================
# Epoch[48/100] - Train loss: 0.10683 Train Accucracy: 0.96938 || Validation Loss: 0.16062 Validation Accuracy: 0.95320
# ====================================================================================================
# Epoch[49/100] - Train loss: 0.10603 Train Accucracy: 0.96925 || Validation Loss: 0.16100 Validation Accuracy: 0.95230
# ====================================================================================================
# Epoch[50/100] - Train loss: 0.10670 Train Accucracy: 0.96930 || Validation Loss: 0.16201 Validation Accuracy: 0.95240
# ====================================================================================================
# Epoch[51/100] - Train loss: 0.10419 Train Accucracy: 0.96990 || Validation Loss: 0.16074 Validation Accuracy: 0.95210
# ====================================================================================================
# Epoch[52/100] - Train loss: 0.10328 Train Accucracy: 0.97002 || Validation Loss: 0.16185 Validation Accuracy: 0.95220
# ====================================================================================================
# Epoch[53/100] - Train loss: 0.10228 Train Accucracy: 0.97075 || Validation Loss: 0.16227 Validation Accuracy: 0.95120
# ====================================================================================================
# Epoch[54/100] - Train loss: 0.10242 Train Accucracy: 0.97017 || Validation Loss: 0.16350 Validation Accuracy: 0.95100
# ====================================================================================================
# Early stopping: Epoch - 53
# 768.4280226230621 초

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# ## 큰모델

# %%
class BigModel(nn.Module):
    
    def __init__(self):
        super().__init__()
        # 개별 linear를 블록으로 묶음
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.ReLU())
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU())
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU())
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU())
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU())
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU())
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU())
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(BigModel(), (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# BigModel                                 [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-4                       [100, 1024]               2,098,176
# │    └─ReLU: 2-5                         [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-6                       [100, 512]                524,800
# │    └─ReLU: 2-7                         [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-8                       [100, 256]                131,328
# │    └─ReLU: 2-9                         [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-10                      [100, 128]                32,896
# │    └─ReLU: 2-11                        [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-12                      [100, 64]                 8,256
# │    └─ReLU: 2-13                        [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-14                      [100, 32]                 2,080
# │    └─ReLU: 2-15                        [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
big_model = BigModel().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(big_model.parameters(), lr=lr)

result = fit(train_loader, test_loader, big_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.15972 Train Accucracy: 0.95547 || Validation Loss: 0.17262 Validation Accuracy: 0.95000
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.09809 Train Accucracy: 0.97167 || Validation Loss: 0.12159 Validation Accuracy: 0.96320
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.05551 Train Accucracy: 0.98407 || Validation Loss: 0.08400 Validation Accuracy: 0.97540
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.04134 Train Accucracy: 0.98740 || Validation Loss: 0.08324 Validation Accuracy: 0.97760
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.05400 Train Accucracy: 0.98300 || Validation Loss: 0.11396 Validation Accuracy: 0.96820
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.04326 Train Accucracy: 0.98625 || Validation Loss: 0.09697 Validation Accuracy: 0.97210
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.01588 Train Accucracy: 0.99562 || Validation Loss: 0.06786 Validation Accuracy: 0.98390
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.01765 Train Accucracy: 0.99463 || Validation Loss: 0.07863 Validation Accuracy: 0.98200
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.01582 Train Accucracy: 0.99513 || Validation Loss: 0.07913 Validation Accuracy: 0.97990
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.01445 Train Accucracy: 0.99567 || Validation Loss: 0.07968 Validation Accuracy: 0.97950
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.03655 Train Accucracy: 0.99027 || Validation Loss: 0.09440 Validation Accuracy: 0.97570
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.01778 Train Accucracy: 0.99487 || Validation Loss: 0.09639 Validation Accuracy: 0.97710
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.01456 Train Accucracy: 0.99602 || Validation Loss: 0.08762 Validation Accuracy: 0.97980
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.01251 Train Accucracy: 0.99633 || Validation Loss: 0.09075 Validation Accuracy: 0.98070
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.02395 Train Accucracy: 0.99362 || Validation Loss: 0.11924 Validation Accuracy: 0.97740
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.00933 Train Accucracy: 0.99733 || Validation Loss: 0.09725 Validation Accuracy: 0.98060
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.00687 Train Accucracy: 0.99790 || Validation Loss: 0.08483 Validation Accuracy: 0.98310
# ====================================================================================================
# Early stopping: Epoch - 16
# 649.2754263877869 초

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# # Dropout 예제
#
# -   dropout 각 레이어에 적용
#     -   dropout은 nn.Dropout 객체를 사용
#     -   객체 생성시 dropout_rate 설정: 0.2 ~ 0.5
#     -   Drop시킬 노드를 가진 Layer 뒤에 추가한다.

# %%
# Dropout Layer적용: nn.Linear -> nn.Relu -> nn.Dropout
# 필수적으로 들어간다
class DropOutModel(nn.Module):
    
    def __init__(self, dropout_rate=0.5):
        super().__init__()
        # 개별 linear를 블록으로 묶음
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %%
summary(DropOutModel(), (100, 1, 28, 28))
# Out:
# ==========================================================================================
# Layer (type:depth-idx)                   Output Shape              Param #
# ==========================================================================================
# DropOutModel                             [100, 10]                 --
# ├─Sequential: 1-1                        [100, 2048]               --
# │    └─Flatten: 2-1                      [100, 784]                --
# │    └─Linear: 2-2                       [100, 2048]               1,607,680
# │    └─ReLU: 2-3                         [100, 2048]               --
# │    └─Dropout: 2-4                      [100, 2048]               --
# ├─Sequential: 1-2                        [100, 1024]               --
# │    └─Linear: 2-5                       [100, 1024]               2,098,176
# │    └─ReLU: 2-6                         [100, 1024]               --
# │    └─Dropout: 2-7                      [100, 1024]               --
# ├─Sequential: 1-3                        [100, 512]                --
# │    └─Linear: 2-8                       [100, 512]                524,800
# │    └─ReLU: 2-9                         [100, 512]                --
# │    └─Dropout: 2-10                     [100, 512]                --
# ├─Sequential: 1-4                        [100, 256]                --
# │    └─Linear: 2-11                      [100, 256]                131,328
# │    └─ReLU: 2-12                        [100, 256]                --
# │    └─Dropout: 2-13                     [100, 256]                --
# ├─Sequential: 1-5                        [100, 128]                --
# │    └─Linear: 2-14                      [100, 128]                32,896
# │    └─ReLU: 2-15                        [100, 128]                --
# │    └─Dropout: 2-16                     [100, 128]                --
# ├─Sequential: 1-6                        [100, 64]                 --
# │    └─Linear: 2-17                      [100, 64]                 8,256
# │    └─ReLU: 2-18                        [100, 64]                 --
# │    └─Dropout: 2-19                     [100, 64]                 --
# ├─Sequential: 1-7                        [100, 32]                 --
# │    └─Linear: 2-20                      [100, 32]                 2,080
# │    └─ReLU: 2-21                        [100, 32]                 --
# │    └─Dropout: 2-22                     [100, 32]                 --
# ├─Linear: 1-8                            [100, 10]                 330
# ==========================================================================================
# Total params: 4,405,546
# Trainable params: 4,405,546
# Non-trainable params: 0
# Total mult-adds (Units.MEGABYTES): 440.55
# ==========================================================================================
# Input size (MB): 0.31
# Forward/backward pass size (MB): 3.26
# Params size (MB): 17.62
# Estimated Total Size (MB): 21.20
# ==========================================================================================

# %%
d_model = DropOutModel().to(device)
loss_fn = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(d_model.parameters(), lr=lr)

result = fit(train_loader, test_loader, d_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode='multi')
# Out:
# Epoch[1/100] - Train loss: 0.77360 Train Accucracy: 0.64720 || Validation Loss: 0.77130 Validation Accuracy: 0.64720
# ====================================================================================================
# Epoch[2/100] - Train loss: 0.50470 Train Accucracy: 0.84562 || Validation Loss: 0.50797 Validation Accuracy: 0.84430
# ====================================================================================================
# Epoch[3/100] - Train loss: 0.31624 Train Accucracy: 0.91773 || Validation Loss: 0.33657 Validation Accuracy: 0.91690
# ====================================================================================================
# Epoch[4/100] - Train loss: 0.19900 Train Accucracy: 0.95718 || Validation Loss: 0.23517 Validation Accuracy: 0.95360
# ====================================================================================================
# Epoch[5/100] - Train loss: 0.16550 Train Accucracy: 0.96350 || Validation Loss: 0.21198 Validation Accuracy: 0.95870
# ====================================================================================================
# Epoch[6/100] - Train loss: 0.14314 Train Accucracy: 0.96735 || Validation Loss: 0.19895 Validation Accuracy: 0.96210
# ====================================================================================================
# Epoch[7/100] - Train loss: 0.12795 Train Accucracy: 0.97112 || Validation Loss: 0.18111 Validation Accuracy: 0.96480
# ====================================================================================================
# Epoch[8/100] - Train loss: 0.11347 Train Accucracy: 0.97600 || Validation Loss: 0.17187 Validation Accuracy: 0.96980
# ====================================================================================================
# Epoch[9/100] - Train loss: 0.10791 Train Accucracy: 0.97540 || Validation Loss: 0.15820 Validation Accuracy: 0.96700
# ====================================================================================================
# Epoch[10/100] - Train loss: 0.08779 Train Accucracy: 0.97918 || Validation Loss: 0.14936 Validation Accuracy: 0.97190
# ====================================================================================================
# Epoch[11/100] - Train loss: 0.07790 Train Accucracy: 0.98262 || Validation Loss: 0.19298 Validation Accuracy: 0.97450
# ====================================================================================================
# Epoch[12/100] - Train loss: 0.08129 Train Accucracy: 0.98087 || Validation Loss: 0.15456 Validation Accuracy: 0.97200
# ====================================================================================================
# Epoch[13/100] - Train loss: 0.07259 Train Accucracy: 0.98300 || Validation Loss: 0.14696 Validation Accuracy: 0.97360
# ====================================================================================================
# Epoch[14/100] - Train loss: 0.07140 Train Accucracy: 0.98295 || Validation Loss: 0.15034 Validation Accuracy: 0.97380
# ====================================================================================================
# Epoch[15/100] - Train loss: 0.07135 Train Accucracy: 0.98420 || Validation Loss: 0.17216 Validation Accuracy: 0.97510
# ====================================================================================================
# Epoch[16/100] - Train loss: 0.06469 Train Accucracy: 0.98487 || Validation Loss: 0.15869 Validation Accuracy: 0.97440
# ====================================================================================================
# Epoch[17/100] - Train loss: 0.05609 Train Accucracy: 0.98727 || Validation Loss: 0.15069 Validation Accuracy: 0.97800
# ====================================================================================================
# Epoch[18/100] - Train loss: 0.04697 Train Accucracy: 0.98897 || Validation Loss: 0.14554 Validation Accuracy: 0.98060
# ====================================================================================================
# Epoch[19/100] - Train loss: 0.06432 Train Accucracy: 0.98385 || Validation Loss: 0.16152 Validation Accuracy: 0.97300
# ====================================================================================================
# Epoch[20/100] - Train loss: 0.04728 Train Accucracy: 0.98940 || Validation Loss: 0.16686 Validation Accuracy: 0.98000
# ====================================================================================================
# Epoch[21/100] - Train loss: 0.05152 Train Accucracy: 0.98757 || Validation Loss: 0.12900 Validation Accuracy: 0.97700
# ====================================================================================================
# Epoch[22/100] - Train loss: 0.05201 Train Accucracy: 0.98677 || Validation Loss: 0.12347 Validation Accuracy: 0.97800
# ====================================================================================================
# Epoch[23/100] - Train loss: 0.04844 Train Accucracy: 0.98743 || Validation Loss: 0.13495 Validation Accuracy: 0.97660
# ====================================================================================================
# Epoch[24/100] - Train loss: 0.03998 Train Accucracy: 0.99105 || Validation Loss: 0.17204 Validation Accuracy: 0.97840
# ====================================================================================================
# Epoch[25/100] - Train loss: 0.03789 Train Accucracy: 0.99112 || Validation Loss: 0.13938 Validation Accuracy: 0.98090
# ====================================================================================================
# Epoch[26/100] - Train loss: 0.04480 Train Accucracy: 0.98893 || Validation Loss: 0.16058 Validation Accuracy: 0.97810
# ====================================================================================================
# Epoch[27/100] - Train loss: 0.03502 Train Accucracy: 0.99190 || Validation Loss: 0.14981 Validation Accuracy: 0.98070
# ====================================================================================================
# Epoch[28/100] - Train loss: 0.03802 Train Accucracy: 0.99183 || Validation Loss: 0.16559 Validation Accuracy: 0.98100
# ====================================================================================================
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 5
#       2 loss_fn = nn.CrossEntropyLoss()
#       3 optimizer = torch.optim.Adam(d_model.parameters(), lr=lr)
# ----> 5 result = fit(train_loader, test_loader, d_model, loss_fn, optimizer, epochs, save_best_model=False, device=device, mode='multi')
#
# File c:\documents\SKN21\07_deeplearning_pytorch\module\train.py:149, in fit(train_loader, val_loader, model, loss_fn, optimizer, epochs, save_best_model, save_model_path, early_stopping, patience, device, mode, lr_scheduler)
#     147 s = time.time()
#     148 for epoch in range(epochs):
# --> 149     train_loss, train_accuracy = train(train_loader, model, loss_fn, optimizer, device=device, mode=mode)
#     150     ############ 1 epoch 학습 종료 -> LR 를 변경 ###########
#     151     if lr_scheduler is not None:
#
# File c:\documents\SKN21\07_deeplearning_pytorch\module\train.py:93, in train(dataloader, model, loss_fn, optimizer, device, mode)
#      90     loss = loss_fn(pred, y)
#      92     optimizer.zero_grad()
# ---> 93     loss.backward()
#      94     optimizer.step()
#      96 if mode == 'binary':
#
# File c:\documents\SKN21\07_deeplearning_pytorch\.venv\Lib\site-packages\torch\_tensor.py:625, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     615 if has_torch_function_unary(self):
#     616     return handle_torch_function(
#     617         Tensor.backward,
#     618         (self,),
#    (...)    623         inputs=inputs,
#     624     )
# --> 625 torch.autograd.backward(
#     626     self, gradient, retain_graph, create_graph, inputs=inputs
#     627 )
#
# File c:\documents\SKN21\07_deeplearning_pytorch\.venv\Lib\site-packages\torch\autograd\__init__.py:354, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     349     retain_graph = create_graph
#     351 # The reason we repeat the same comment below is that
#     352 # some Python versions print out the first line of a multi-line function
#     353 # calls in the traceback and some print out the last line
# --> 354 _engine_run_backward(
#     355     tensors,
#     356     grad_tensors_,
#     357     retain_graph,
#     358     create_graph,
#     359     inputs_tuple,
#     360     allow_unreachable=True,
#     361     accumulate_grad=True,
#     362 )
#
# File c:\documents\SKN21\07_deeplearning_pytorch\.venv\Lib\site-packages\torch\autograd\graph.py:841, in _engine_run_backward(t_outputs, *args, **kwargs)
#     839     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840 try:
# --> 841     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842         t_outputs, *args, **kwargs
#     843     )  # Calls into the C++ engine to run the backward pass
#     844 finally:
#     845     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %%
plot_fit_result(result[0], result[1], result[2], result[3])

# %% [markdown]
# # Batch Normalization
#
# - Dense 와 Activation 사이에 정의한다.

# %%
# BatchNorm1d Layer적용: nn.Linear -> nn.BatchNorm1d -> nn.ReLU -> nn.Dropout
class BatchNormModel(nn.Module):
    
    def __init__(self, dropout_rate=0.5):
        super().__init__()
        # 개별 linear를 블록으로 묶음
        self.b1 = nn.Sequential(nn.Flatten(), nn.Linear(784, 2048), nn.BatchNorm1d(2048), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b2 = nn.Sequential(nn.Linear(2048, 1024), nn.BatchNorm1d(1024), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b3 = nn.Sequential(nn.Linear(1024, 512), nn.BatchNorm1d(512), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b4 = nn.Sequential(nn.Linear(512, 256), nn.BatchNorm1d(256), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b5 = nn.Sequential(nn.Linear(256, 128), nn.BatchNorm1d(128), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b6 = nn.Sequential(nn.Linear(128, 64), nn.BatchNorm1d(64), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.b7 = nn.Sequential(nn.Linear(64, 32), nn.BatchNorm1d(32), nn.ReLU(), nn.Dropout(p=dropout_rate))
        self.out_layer = nn.Linear(32, 10)

    def forward(self, X):
        out = self.b1(X)
        out = self.b2(out)
        out = self.b3(out)
        out = self.b4(out)
        out = self.b5(out)
        out = self.b6(out)
        out = self.b7(out)
        out = self.out_layer(out)
        return out

# %% [markdown]
# # Learning rate decay

# %% [markdown]
# ### Optimizer와 Learning rate scheduler의 속성, 메소드 확인
#
# -   파이토치는 `torch.optim` 모듈에서 다양한 Learning rate 알고리즘을 제공한다.

# %%
import matplotlib.pyplot as plt

def plot_lr(title, lr_list):
    """Learning 스케쥴러(학습도중 LR를 변경시키는 객체.)에 의해 변화되는 Learning Rate값을 시각화.

    Args:
        title (str): title
        lr_list (list): Learning Rate 스케쥴러에 의해 변경된 learning rate값들을 가지는 list
    """
    plt.figure(figsize=(15, 6))
    plt.plot(range(len(lr_list)), lr_list)

    plt.title(title)
    xticks = [x for x in range(len(lr_list)) if x % 10 == 0] # 눈금을 10 배수 자리에 위치.
    plt.xticks(xticks)
    plt.xlabel("Epoch 수 또는 Step 수")
    plt.ylabel("학습률-LR")
    plt.grid(True, linestyle=":")
    plt.show()

# %%
lr = 0.001
moel = BatchNormModel()
optimizer = torch.optim.Adam(model.parameteres(), lr=lr)

# %%
# optimizer의 현재 lr 조회
optimizer.param_groups[0]['lr']

# %% [markdown]
# #### StepLR

# %%
# 특정 epoch/step 마다 특정 비율로 lr을 변경(보통을 줄여나간다.)
# 1. LearningRate Scheduler 객체 생성
step_lr_scheduler = torch.optim.lr_scheduler.StepLR(
    optimizer,      # 학습률을 변경할 optimizer
    step_size=30,   # 몇 epoch/step 당 lr을 변경할 지 설정. lr_scheduler.step() - 지정한 횟수(여기서는 30번)만큼 호출하면 변경(epoch으로 호출하면 epoch)
    gamma=0.5       # 변경할 비율. 새LR = 현재 lr * gamma 
)

step_lr_scheduler.get_last_lr() # optimizer 현재 lr 조회

# %%
# 학습
lr_list = [] # 스케줄러에게 lr 변경 요청 후 lr을 저장
epochs = 300
step_size = 20 # for x, y in dataloader: 이 반복횟수 1 epoch당 몇번 학습할 지
for epoch in range(epochs):
    # 1 epoch 학습
    for step in range(step_size): # for x, y in dataloader
        # 배치 만큼 학습데이터를 가져와서 1 step 학습
        # 1. x, y를 device로 이동
        # 2. model 추론
        # 3. loss 계산
        # 4. 파라미터들의 gradient 게산
        # 5. 파라미터 업데이트
        optimizer.step()
        # 6. 파라미터의 gradient 초기화
        optimizer.zero_grad()
    # lr 스케줄러를 이용해서 lr을 변경(스케줄에 맞춰서 변경)
    step_lr_scheduler.step()
    lr_list.append(step_lr_scheduler.get_last_lr()[0])

# %%
plt.rcParams['font.family'] = 'malgun gothic'
plt.rcParams['axes.unicode_minus'] = False
plot_lr('StepLR', lr_list)

# %% [markdown]
# #### CosineAnnealingLR
#
# cosine 그래프를 그리면서 learning rate를 변경 하는 방식.
# 최근에는 learning rate를 단순히 감소시키기 보다는 감소와 증가를 반복하여 진동하는 방식으로 최적점을 찾아가는 알고리즘을 많이 사용한다. 이러한 방법 중 가장 간단하면서도 많이 사용되는 방법이 CosineAnnealingLR이다.

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
ca_lr_sch = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=20,       # 변화주기 epoch/step(내려가는 주기, 올라가는 주기)
    eta_min=1e-6    # lr 최소값을 지정, 어디까지 내릴지
)

# 초기 lr ~ eta_min 사이를 올라갔다 내려갔다 한다.

# %%
lr_list = []
for epoch in range(epochs):
    for step in range(step_size):
        optimizer.step()
        optimizer.zero_grad()

    ca_lr_sch.step()
    lr_list.append(ca_lr_sch.get_last_lr()[0])

# %%
lr_list

# %% [markdown]
# #### CosineAnnealingWarmRestarts
#
# cosine annealing의 스케쥴링에 cosine 주기의 에폭을 점점 늘리거나 줄일 수 있다. (보통 늘린다.)

# %%
optimizer = torch.optim.Adam(model.parameters(), lr=lr)
cawr_lr_sche = torch.optim.lr_scheduler.CosineAnnealingWarmRestarts(
    optimizer,
    T_0=10,    # 변화주기. (CosineAnnealingLR의 T_max)
    T_mult=2,  # 새로운 변화주기(새 변화주기(T_0) = 현재 변화 주기(T_0) * T_mult )
    eta_min=1e-6
)

# %%
lr_list = []
for epoch in range(epoch):

    for step in range(step_size):
        optimizer.step()
        optimizer.zero_grad()

    cawr_lr_sche.step()
    lr_list.append(cawr_lr_sche.get_last_lr()[0])

# %%
plot_lr('CosineAnnealingWarmRestart', lr_list)
